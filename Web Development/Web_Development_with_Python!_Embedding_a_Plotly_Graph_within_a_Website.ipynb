# %%
import plotly.express as px

# %%
experience_dict = {'Programming Language': ['Excel', 'Python', 'Tableau', 'R', 'Bash', 'PowerShell'], 'Years of Experience (As of April 2022)': [8,4,3,2,1,1]}

fig = px.bar(experience_dict, x='Programming Language', y='Years of Experience (As of April 2022)',color_discrete_sequence=["white"])

fig.update_layout(
    paper_bgcolor = "rgba(0,0,0,0)",
    plot_bgcolor = "rgba(0,0,0,0)",
    font_color = 'white',
    font_family = 'verdana',
    font_size = 20,
    )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html("skills.html")

# %% [markdown]
# # **References and Additional Learning**

# %% [markdown]
# ## **Websites**
#
# - **[Plotly Express in Python](https://plotly.com/python/plotly-express/) from Plotly.com**
#
# - **[Creating and Updating Figures in Python](https://plotly.com/python/creating-and-updating-figures/) from Plotly.com**
#
# - **[Embedding Graphs in HTML in Python](https://plotly.com/python/embedding-plotly-graphs-in-HTML/) from Plotly.com**

# %% [markdown]
# # **Connect**
# - **Feel free to connect with Adrian on [YouTube](https://www.youtube.com/channel/UCPuDxI3xb_ryUUMfkm0jsRA), [LinkedIn](https://www.linkedin.com/in/adrian-dolinay-frm-96a289106/), [Twitter](https://twitter.com/DolinayG), [GitHub](https://github.com/ad17171717) and [Odysee](https://odysee.com/@adriandolinay:0). Happy coding!**
