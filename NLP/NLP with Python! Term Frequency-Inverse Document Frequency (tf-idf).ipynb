# %%
import string
import math
import pandas as pd
pd.set_option('display.max_rows', 500)
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# %% [markdown]
# # **Data Set**

# %%
news_headlines = ['Stocks Slide After Jobless Claims Rise',
                   'Jobless Claims Rose Last Week, Still Historically Low',
                   'Stocks Extend Losses, Reversing Early-Week Gains',
                   'Jobless Claims Are Expected to Rise',
                   'More Americans apply for jobless benefits last week',
                   'NFL Week 4 Offense Rankings | NFL News, Rankings and Statistics',
                   'NFL rankings, figuring out the Ravens offense, Kenny Pickett gets the nod',
                   "Week 4's NFL Team of the Week - Offense",
                   '2022 NFL offense rankings',
                   'How Will Every NFL Offense Perform in 2022?']

# %% [markdown]
# # **Preprocess Text**

# %% [markdown]
# ## **Remove Stop Words, turn characters into lowercase and remove punctuation**

# %%
stop_words = stopwords.words('english')

# %%
def stop_word_removal(text, stop_word_corpus, punct_str):
    clean_text = ' '.join([word.lower() for word in text.split() if word.lower()
                 not in stop_word_corpus]).replace('\n',' ')
    return clean_text.translate(str.maketrans('', '', punct_str))

# %%
news_cleaned = [stop_word_removal(headline,stop_words,string.punctuation)
                for headline in news_headlines]

news_cleaned
# Out:
# ['stocks slide jobless claims rise',
#  'jobless claims rose last week still historically low',
#  'stocks extend losses reversing earlyweek gains',
#  'jobless claims expected rise',
#  'americans apply jobless benefits last week',
#  'nfl week 4 offense rankings  nfl news rankings statistics',
#  'nfl rankings figuring ravens offense kenny pickett gets nod',
#  'week 4s nfl team week  offense',
#  '2022 nfl offense rankings',
#  'every nfl offense perform 2022']

# %% [markdown]
# # **Term Frequency (tf)**
#
# **Term frequency, $tf(t,d)$, is the relative frequency of term $t$ within document $d$**
#
# $\text{Term Frequency = }\large{\frac{f_{t,d}}{\sum_{t' \in d}f_{t',d}}}$ **, where the numerator represents the count of a given term and the denominator is the total number of terms in document $d$**

# %% [markdown]
# <sup>Source: [tf–idf](https://en.wikipedia.org/wiki/Tf%E2%80%93idf) from Wikipedia.org<sup/>

# %%
def term_freq(document_list):
    
    combined_string = ' '.join(document_list)
    word_set = [word for word in set(combined_string.split()) if len(word) > 1]
    
    filtered_docs = []
    for document in document_list:
        filtered_docs.append(' '.join([word for word in document.split() if len(word) > 1]))
        
    doc_word_count = []
    for document in filtered_docs:
        doc_word_count.append([document.split().count(word)/len(document.split()) for word in word_set])
    
    return {doc:vector for doc,vector in zip(filtered_docs,doc_word_count)}

# %%
def word_list(document_list):
    
    combined_string = ' '.join(document_list)
    return [word for word in set(combined_string.split()) if len(word) > 1]

# %%
tf_df = pd.DataFrame(data= term_freq(news_cleaned).values(),
                     columns = word_list(news_cleaned),
                     index = term_freq(news_cleaned).keys())

tf_df
# Out:
#                                                         last  historically  \
# stocks slide jobless claims rise                    0.000000         0.000
# jobless claims rose last week still historicall...  0.125000         0.125
# stocks extend losses reversing earlyweek gains      0.000000         0.000
# jobless claims expected rise                        0.000000         0.000
# americans apply jobless benefits last week          0.166667         0.000
# nfl week offense rankings nfl news rankings sta...  0.000000         0.000
# nfl rankings figuring ravens offense kenny pick...  0.000000         0.000
# week 4s nfl team week offense                       0.000000         0.000
# 2022 nfl offense rankings                           0.000000         0.000
# every nfl offense perform 2022                      0.000000         0.000
#
#                                                     reversing    low   rose  \
# stocks slide jobless claims rise                     0.000000  0.000  0.000
# jobless claims rose last week still historicall...   0.000000  0.125  0.125
# stocks extend losses reversing earlyweek gains       0.166667  0.000  0.000
# jobless claims expected rise                         0.000000  0.000  0.000
# americans apply jobless benefits last week           0.000000  0.000  0.000
# nfl week offense rankings nfl news rankings sta...   0.000000  0.000  0.000
# nfl rankings figuring ravens offense kenny pick...   0.000000  0.000  0.000
# week 4s nfl team week offense                        0.000000  0.000  0.000
# 2022 nfl offense rankings                            0.000000  0.000  0.000
# every nfl offense perform 2022                       0.000000  0.000  0.000
#
#                                                       losses      gets  \
# stocks slide jobless claims rise                    0.000000  0.000000
# jobless claims rose last week still historicall...  0.000000  0.000000
# stocks extend losses reversing earlyweek gains      0.166667  0.000000
# jobless claims expected rise                        0.000000  0.000000
# americans apply jobless benefits last week          0.000000  0.000000
# nfl week offense rankings nfl news rankings sta...  0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.111111
# week 4s nfl team week offense                       0.000000  0.000000
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.000000
#
#                                                       ravens       nfl  \
# stocks slide jobless claims rise                    0.000000  0.000000
# jobless claims rose last week still historicall...  0.000000  0.000000
# stocks extend losses reversing earlyweek gains      0.000000  0.000000
# jobless claims expected rise                        0.000000  0.000000
# americans apply jobless benefits last week          0.000000  0.000000
# nfl week offense rankings nfl news rankings sta...  0.000000  0.250000
# nfl rankings figuring ravens offense kenny pick...  0.111111  0.111111
# week 4s nfl team week offense                       0.000000  0.166667
# 2022 nfl offense rankings                           0.000000  0.250000
# every nfl offense perform 2022                      0.000000  0.200000
#
#                                                     statistics  ...       nod  \
# stocks slide jobless claims rise                         0.000  ...  0.000000
# jobless claims rose last week still historicall...       0.000  ...  0.000000
# stocks extend losses reversing earlyweek gains           0.000  ...  0.000000
# jobless claims expected rise                             0.000  ...  0.000000
# americans apply jobless benefits last week               0.000  ...  0.000000
# nfl week offense rankings nfl news rankings sta...       0.125  ...  0.000000
# nfl rankings figuring ravens offense kenny pick...       0.000  ...  0.111111
# week 4s nfl team week offense                            0.000  ...  0.000000
# 2022 nfl offense rankings                                0.000  ...  0.000000
# every nfl offense perform 2022                           0.000  ...  0.000000
#
#                                                      news      week  perform  \
# stocks slide jobless claims rise                    0.000  0.000000      0.0
# jobless claims rose last week still historicall...  0.000  0.125000      0.0
# stocks extend losses reversing earlyweek gains      0.000  0.000000      0.0
# jobless claims expected rise                        0.000  0.000000      0.0
# americans apply jobless benefits last week          0.000  0.166667      0.0
# nfl week offense rankings nfl news rankings sta...  0.125  0.125000      0.0
# nfl rankings figuring ravens offense kenny pick...  0.000  0.000000      0.0
# week 4s nfl team week offense                       0.000  0.333333      0.0
# 2022 nfl offense rankings                           0.000  0.000000      0.0
# every nfl offense perform 2022                      0.000  0.000000      0.2
#
#                                                     americans     kenny  \
# stocks slide jobless claims rise                     0.000000  0.000000
# jobless claims rose last week still historicall...   0.000000  0.000000
# stocks extend losses reversing earlyweek gains       0.000000  0.000000
# jobless claims expected rise                         0.000000  0.000000
# americans apply jobless benefits last week           0.166667  0.000000
# nfl week offense rankings nfl news rankings sta...   0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...   0.000000  0.111111
# week 4s nfl team week offense                        0.000000  0.000000
# 2022 nfl offense rankings                            0.000000  0.000000
# every nfl offense perform 2022                       0.000000  0.000000
#
#                                                     claims   jobless  slide  \
# stocks slide jobless claims rise                     0.200  0.200000    0.2
# jobless claims rose last week still historicall...   0.125  0.125000    0.0
# stocks extend losses reversing earlyweek gains       0.000  0.000000    0.0
# jobless claims expected rise                         0.250  0.250000    0.0
# americans apply jobless benefits last week           0.000  0.166667    0.0
# nfl week offense rankings nfl news rankings sta...   0.000  0.000000    0.0
# nfl rankings figuring ravens offense kenny pick...   0.000  0.000000    0.0
# week 4s nfl team week offense                        0.000  0.000000    0.0
# 2022 nfl offense rankings                            0.000  0.000000    0.0
# every nfl offense perform 2022                       0.000  0.000000    0.0
#
#                                                      pickett
# stocks slide jobless claims rise                    0.000000
# jobless claims rose last week still historicall...  0.000000
# stocks extend losses reversing earlyweek gains      0.000000
# jobless claims expected rise                        0.000000
# americans apply jobless benefits last week          0.000000
# nfl week offense rankings nfl news rankings sta...  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.111111
# week 4s nfl team week offense                       0.000000
# 2022 nfl offense rankings                           0.000000
# every nfl offense perform 2022                      0.000000
#
# [10 rows x 36 columns]

# %% [markdown]
# # **Inverse Document Frequency (idf)**
#
# **The inverse document frequency (idf) is a measure of importance of a term $t$ in a given document $d$. The measure gives a larger weight to terms which are less common in the corpus while more frequent terms across a document are given less weight.**
#
# **The below idf formula differs from the standard idf contained in academic textbooks. The Sci-Kit Learn module adds a `1` in the numerator and the denominator which is akin to adding a document to the corpus containing every term to prevent a division by zero. Sci-Kit Learn also adds a `1` to the quotient in the formula.**
#
# $\text{Inverse Document Frequency = } log \large{\frac{| \ D \ | + 1}{{| \ d : t_i \in \ d  \ | + 1}}} + 1$, **where $D$ is the corpus (total number of documents), and $d_{ti}$ is the number of documents the given term $t$ appears in**

# %% [markdown]
# <sup>Source: [Text Mining and Network Analysis of Digital Libraries in R](https://www.sciencedirect.com/science/article/pii/B9780124115118000049) by Eric Nguyen<sup/>
#
# <sup>Source: [“Sklearn’s TF-IDF” vs “Standard TF-IDF”](https://towardsdatascience.com/how-sklearns-tf-idf-is-different-from-the-standard-tf-idf-275fa582e73d) by Siva Sivarajah from Towards Data Science<sup/>

# %%
def inverse_doc_freq(document_list,unique_words):
    
    
    idf_dict = {}
    
    for word in unique_words:
        temp_word_list = []
        for sentence in document_list:
            temp_word_list.append(word in sentence)
        idf_dict[word] = temp_word_list.count(True)+1
        
    idf_list = []

    for value in idf_dict.values():
        idf_list.append(math.log((len(tf_df)+1)/value)+1)
        
    return idf_list

# %%
idf_array = inverse_doc_freq(tf_df.index,tf_df.columns)
idf_array
# Out:
# [2.2992829841302607,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  1.6061358035703155,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.2992829841302607,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.2992829841302607,
#  2.7047480922384253,
#  2.01160091167848,
#  2.2992829841302607,
#  2.7047480922384253,
#  1.6061358035703155,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  1.6061358035703155,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.7047480922384253,
#  2.01160091167848,
#  1.7884573603642702,
#  2.7047480922384253,
#  2.7047480922384253]

# %% [markdown]
# # **Term Frequency-Inverse Document Frequency (tf-idf)**
#
# **The term frequency-inverse document frequency (tf-idf), is an array of values that represents how important a word is in a given document within a corpus. The higher the tf-idf value is for a word in a document, the more important the word is.**
#
# $\text{tf-idf Product = (Term Frequency)(Inverse Document Frequency)}$
#
# $\text{tf-idf =} \Large{\frac{\text{tf-idf Product}}{||\text{tf-idf Product}||}}$

# %% [markdown]
# <sup>Source: [tf–idf](https://en.wikipedia.org/wiki/Tf%E2%80%93idf) from Wikipedia.org<sup/>
#
# <sup>Source: [“Sklearn’s TF-IDF” vs “Standard TF-IDF”](https://towardsdatascience.com/how-sklearns-tf-idf-is-different-from-the-standard-tf-idf-275fa582e73d) by Siva Sivarajah from Towards Data Science<sup/>

# %%
def tf_idf(term_freq_data,inverse_doc_freq_data):
    
    tf_idf_vector = []
    multiplied_vector = term_freq_data * inverse_doc_freq_data
    
    for array in multiplied_vector:
        tf_idf_vector.append(array/(sum(array**2))**.5)
        
    return tf_idf_vector

# %% [markdown]
# # **Saving the TF-IDF Vector to a pandas DataFrame**

# %%
tfidf_df = pd.DataFrame(data = tf_idf(tf_df.to_numpy(), np.array(idf_array)),
             columns = word_list(news_cleaned),
             index = term_freq(news_cleaned).keys())

tfidf_df
# Out:
#                                                         last  historically  \
# stocks slide jobless claims rise                    0.000000      0.000000
# jobless claims rose last week still historicall...  0.345166      0.406033
# stocks extend losses reversing earlyweek gains      0.000000      0.000000
# jobless claims expected rise                        0.000000      0.000000
# americans apply jobless benefits last week          0.400181      0.000000
# nfl week offense rankings nfl news rankings sta...  0.000000      0.000000
# nfl rankings figuring ravens offense kenny pick...  0.000000      0.000000
# week 4s nfl team week offense                       0.000000      0.000000
# 2022 nfl offense rankings                           0.000000      0.000000
# every nfl offense perform 2022                      0.000000      0.000000
#
#                                                     reversing       low  \
# stocks slide jobless claims rise                     0.000000  0.000000
# jobless claims rose last week still historicall...   0.000000  0.406033
# stocks extend losses reversing earlyweek gains       0.418024  0.000000
# jobless claims expected rise                         0.000000  0.000000
# americans apply jobless benefits last week           0.000000  0.000000
# nfl week offense rankings nfl news rankings sta...   0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...   0.000000  0.000000
# week 4s nfl team week offense                        0.000000  0.000000
# 2022 nfl offense rankings                            0.000000  0.000000
# every nfl offense perform 2022                       0.000000  0.000000
#
#                                                         rose    losses  \
# stocks slide jobless claims rise                    0.000000  0.000000
# jobless claims rose last week still historicall...  0.406033  0.000000
# stocks extend losses reversing earlyweek gains      0.000000  0.418024
# jobless claims expected rise                        0.000000  0.000000
# americans apply jobless benefits last week          0.000000  0.000000
# nfl week offense rankings nfl news rankings sta...  0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.000000
# week 4s nfl team week offense                       0.000000  0.000000
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.000000
#
#                                                         gets    ravens  \
# stocks slide jobless claims rise                    0.000000  0.000000
# jobless claims rose last week still historicall...  0.000000  0.000000
# stocks extend losses reversing earlyweek gains      0.000000  0.000000
# jobless claims expected rise                        0.000000  0.000000
# americans apply jobless benefits last week          0.000000  0.000000
# nfl week offense rankings nfl news rankings sta...  0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.371176  0.371176
# week 4s nfl team week offense                       0.000000  0.000000
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.000000
#
#                                                          nfl  statistics  ...  \
# stocks slide jobless claims rise                    0.000000    0.000000  ...
# jobless claims rose last week still historicall...  0.000000    0.000000  ...
# stocks extend losses reversing earlyweek gains      0.000000    0.000000  ...
# jobless claims expected rise                        0.000000    0.000000  ...
# americans apply jobless benefits last week          0.000000    0.000000  ...
# nfl week offense rankings nfl news rankings sta...  0.472110    0.397519  ...
# nfl rankings figuring ravens offense kenny pick...  0.220412    0.000000  ...
# week 4s nfl team week offense                       0.292706    0.000000  ...
# 2022 nfl offense rankings                           0.421900    0.000000  ...
# every nfl offense perform 2022                      0.320731    0.000000  ...
#
#                                                          nod      news  \
# stocks slide jobless claims rise                    0.000000  0.000000
# jobless claims rose last week still historicall...  0.000000  0.000000
# stocks extend losses reversing earlyweek gains      0.000000  0.000000
# jobless claims expected rise                        0.000000  0.000000
# americans apply jobless benefits last week          0.000000  0.000000
# nfl week offense rankings nfl news rankings sta...  0.000000  0.397519
# nfl rankings figuring ravens offense kenny pick...  0.371176  0.000000
# week 4s nfl team week offense                       0.000000  0.000000
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.000000
#
#                                                         week   perform  \
# stocks slide jobless claims rise                    0.000000  0.000000
# jobless claims rose last week still historicall...  0.241111  0.000000
# stocks extend losses reversing earlyweek gains      0.000000  0.000000
# jobless claims expected rise                        0.000000  0.000000
# americans apply jobless benefits last week          0.279542  0.000000
# nfl week offense rankings nfl news rankings sta...  0.236055  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.000000
# week 4s nfl team week offense                       0.585412  0.000000
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.540114
#
#                                                     americans     kenny  \
# stocks slide jobless claims rise                     0.000000  0.000000
# jobless claims rose last week still historicall...   0.000000  0.000000
# stocks extend losses reversing earlyweek gains       0.000000  0.000000
# jobless claims expected rise                         0.000000  0.000000
# americans apply jobless benefits last week           0.470751  0.000000
# nfl week offense rankings nfl news rankings sta...   0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...   0.000000  0.371176
# week 4s nfl team week offense                        0.000000  0.000000
# 2022 nfl offense rankings                            0.000000  0.000000
# every nfl offense perform 2022                       0.000000  0.000000
#
#                                                       claims   jobless  \
# stocks slide jobless claims rise                    0.401245  0.356735
# jobless claims rose last week still historicall...  0.301979  0.268481
# stocks extend losses reversing earlyweek gains      0.000000  0.000000
# jobless claims expected rise                        0.451533  0.401445
# americans apply jobless benefits last week          0.000000  0.311274
# nfl week offense rankings nfl news rankings sta...  0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.000000
# week 4s nfl team week offense                       0.000000  0.000000
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.000000
#
#                                                        slide   pickett
# stocks slide jobless claims rise                    0.539504  0.000000
# jobless claims rose last week still historicall...  0.000000  0.000000
# stocks extend losses reversing earlyweek gains      0.000000  0.000000
# jobless claims expected rise                        0.000000  0.000000
# americans apply jobless benefits last week          0.000000  0.000000
# nfl week offense rankings nfl news rankings sta...  0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.371176
# week 4s nfl team week offense                       0.000000  0.000000
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.000000
#
# [10 rows x 36 columns]

# %% [markdown]
# # **Scikit-learn's TfidfVectorizer Class**

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(news_cleaned)

# %%
sklearn_df = pd.DataFrame(data = X.toarray(),columns=vectorizer.get_feature_names_out(),index=news_cleaned)
sklearn_df
# Out:
#                                                         2022        4s  \
# stocks slide jobless claims rise                    0.000000  0.000000
# jobless claims rose last week still historicall...  0.000000  0.000000
# stocks extend losses reversing earlyweek gains      0.000000  0.000000
# jobless claims expected rise                        0.000000  0.000000
# americans apply jobless benefits last week          0.000000  0.000000
# nfl week 4 offense rankings  nfl news rankings ...  0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.000000
# week 4s nfl team week  offense                      0.000000  0.473825
# 2022 nfl offense rankings                           0.603976  0.000000
# every nfl offense perform 2022                      0.459147  0.000000
#
#                                                     americans     apply  \
# stocks slide jobless claims rise                     0.000000  0.000000
# jobless claims rose last week still historicall...   0.000000  0.000000
# stocks extend losses reversing earlyweek gains       0.000000  0.000000
# jobless claims expected rise                         0.000000  0.000000
# americans apply jobless benefits last week           0.466399  0.466399
# nfl week 4 offense rankings  nfl news rankings ...   0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...   0.000000  0.000000
# week 4s nfl team week  offense                       0.000000  0.000000
# 2022 nfl offense rankings                            0.000000  0.000000
# every nfl offense perform 2022                       0.000000  0.000000
#
#                                                     benefits    claims  \
# stocks slide jobless claims rise                    0.000000  0.401245
# jobless claims rose last week still historicall...  0.000000  0.299895
# stocks extend losses reversing earlyweek gains      0.000000  0.000000
# jobless claims expected rise                        0.000000  0.451533
# americans apply jobless benefits last week          0.466399  0.000000
# nfl week 4 offense rankings  nfl news rankings ...  0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.000000
# week 4s nfl team week  offense                      0.000000  0.000000
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.000000
#
#                                                     earlyweek     every  \
# stocks slide jobless claims rise                     0.000000  0.000000
# jobless claims rose last week still historicall...   0.000000  0.000000
# stocks extend losses reversing earlyweek gains       0.418024  0.000000
# jobless claims expected rise                         0.000000  0.000000
# americans apply jobless benefits last week           0.000000  0.000000
# nfl week 4 offense rankings  nfl news rankings ...   0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...   0.000000  0.000000
# week 4s nfl team week  offense                       0.000000  0.000000
# 2022 nfl offense rankings                            0.000000  0.000000
# every nfl offense perform 2022                       0.000000  0.540114
#
#                                                     expected    extend  ...  \
# stocks slide jobless claims rise                    0.000000  0.000000  ...
# jobless claims rose last week still historicall...  0.000000  0.000000  ...
# stocks extend losses reversing earlyweek gains      0.000000  0.418024  ...
# jobless claims expected rise                        0.607119  0.000000  ...
# americans apply jobless benefits last week          0.000000  0.000000  ...
# nfl week 4 offense rankings  nfl news rankings ...  0.000000  0.000000  ...
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.000000  ...
# week 4s nfl team week  offense                      0.000000  0.000000  ...
# 2022 nfl offense rankings                           0.000000  0.000000  ...
# every nfl offense perform 2022                      0.000000  0.000000  ...
#
#                                                       ravens  reversing  \
# stocks slide jobless claims rise                    0.000000   0.000000
# jobless claims rose last week still historicall...  0.000000   0.000000
# stocks extend losses reversing earlyweek gains      0.000000   0.418024
# jobless claims expected rise                        0.000000   0.000000
# americans apply jobless benefits last week          0.000000   0.000000
# nfl week 4 offense rankings  nfl news rankings ...  0.000000   0.000000
# nfl rankings figuring ravens offense kenny pick...  0.371176   0.000000
# week 4s nfl team week  offense                      0.000000   0.000000
# 2022 nfl offense rankings                           0.000000   0.000000
# every nfl offense perform 2022                      0.000000   0.000000
#
#                                                         rise      rose  \
# stocks slide jobless claims rise                    0.458627  0.000000
# jobless claims rose last week still historicall...  0.000000  0.403231
# stocks extend losses reversing earlyweek gains      0.000000  0.000000
# jobless claims expected rise                        0.516107  0.000000
# americans apply jobless benefits last week          0.000000  0.000000
# nfl week 4 offense rankings  nfl news rankings ...  0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.000000
# week 4s nfl team week  offense                      0.000000  0.000000
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.000000
#
#                                                        slide  statistics  \
# stocks slide jobless claims rise                    0.539504    0.000000
# jobless claims rose last week still historicall...  0.000000    0.000000
# stocks extend losses reversing earlyweek gains      0.000000    0.000000
# jobless claims expected rise                        0.000000    0.000000
# americans apply jobless benefits last week          0.000000    0.000000
# nfl week 4 offense rankings  nfl news rankings ...  0.000000    0.394888
# nfl rankings figuring ravens offense kenny pick...  0.000000    0.000000
# week 4s nfl team week  offense                      0.000000    0.000000
# 2022 nfl offense rankings                           0.000000    0.000000
# every nfl offense perform 2022                      0.000000    0.000000
#
#                                                        still    stocks  \
# stocks slide jobless claims rise                    0.000000  0.458627
# jobless claims rose last week still historicall...  0.403231  0.000000
# stocks extend losses reversing earlyweek gains      0.000000  0.355359
# jobless claims expected rise                        0.000000  0.000000
# americans apply jobless benefits last week          0.000000  0.000000
# nfl week 4 offense rankings  nfl news rankings ...  0.000000  0.000000
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.000000
# week 4s nfl team week  offense                      0.000000  0.000000
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.000000
#
#                                                         team      week
# stocks slide jobless claims rise                    0.000000  0.000000
# jobless claims rose last week still historicall...  0.000000  0.266628
# stocks extend losses reversing earlyweek gains      0.000000  0.000000
# jobless claims expected rise                        0.000000  0.000000
# americans apply jobless benefits last week          0.000000  0.308397
# nfl week 4 offense rankings  nfl news rankings ...  0.000000  0.261111
# nfl rankings figuring ravens offense kenny pick...  0.000000  0.000000
# week 4s nfl team week  offense                      0.473825  0.626614
# 2022 nfl offense rankings                           0.000000  0.000000
# every nfl offense perform 2022                      0.000000  0.000000
#
# [10 rows x 36 columns]

# %%
for word in sklearn_df.index[0].split():
    print(word,sklearn_df[0:1][word.lower()][0])
# Out:
# stocks 0.4586274284579443
# slide 0.539503693426004
# jobless 0.3567353847924965
# claims 0.40124480526077394
# rise 0.4586274284579443

# %%
for word in tfidf_df.index[0].split():
    print(word,tfidf_df[0:1][word][0])
# Out:
# stocks 0.4586274284579443
# slide 0.5395036934260039
# jobless 0.3567353847924965
# claims 0.4012448052607739
# rise 0.4586274284579443

# %% [markdown]
# # **References and Additional Learning**

# %% [markdown]
# ## **Article**
#
# - **[“Sklearn’s TF-IDF” vs “Standard TF-IDF”](https://towardsdatascience.com/how-sklearns-tf-idf-is-different-from-the-standard-tf-idf-275fa582e73d) by Siva Sivarajah from Towards Data Science**

# %% [markdown]
# ## **Textbook**
#
# - **[Text Mining and Network Analysis of Digital Libraries in R](https://www.sciencedirect.com/science/article/pii/B9780124115118000049) by Eric Nguyen**

# %% [markdown]
# ## **Websites**
#
# - **[TfidfVectorizer documentation](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html) from Scikit-learn.org**
#
# - **[tf–idf](https://en.wikipedia.org/wiki/Tf%E2%80%93idf) from Wikipedia.org**

# %% [markdown]
# ## **Videos**
#
# - **[NLP with Python! Bag of Words (BoW)](https://www.youtube.com/watch?v=mVF0Lt5Sb84&t=3s) by Adrian Dolinay on YouTube**
#
# - **[NLP with Python! Stop Words](https://www.youtube.com/watch?v=0D7ae7OaaHQ&t=3s) by Adrian Dolinay on YouTube**

# %% [markdown]
# # **Connect**
# - **Feel free to connect with Adrian on [YouTube](https://www.youtube.com/channel/UCPuDxI3xb_ryUUMfkm0jsRA), [LinkedIn](https://www.linkedin.com/in/adrian-dolinay-frm-96a289106/), [Twitter](https://twitter.com/DolinayG), [GitHub](https://github.com/ad17171717) and [Odysee](https://odysee.com/@adriandolinay:0). Happy coding!**
