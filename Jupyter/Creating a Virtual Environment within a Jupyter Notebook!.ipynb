# %% [markdown]
# # **Python Virtual Environments**
#
# **Python virtual environments create a virtual installation of Python inside a project directory. Users can then install and manage Python packages for each project. This allows users to be able to install packages and modify their Python environment without breaking packages installed in other environments.**

# %% [markdown]
# <sup>Source: [Python Virtual Environments](https://www.marquette.edu/high-performance-computing/py-venv.php) from Marquette University<sup/>

# %% [markdown]
# ## **Dependency Issues**

# %% [markdown]
# ![venv_depend.png](attachment:venv_depend.png)

# %% [markdown]
# ## **Package Bloat**

# %% [markdown]
# ![venv_size.png](attachment:venv_size.png)

# %% [markdown]
# # **venv Module**
#
# **The venv module provides support for creating virtual environments with their own site directories, optionally isolated from system site directories. Each virtual environment has its own Python binary (which matches the version of the binary that was used to create this environment) and can have its own independent set of installed Python packages in its site directories.**

# %% [markdown]
# <sup>Source: [venv module](https://docs.python.org/3/library/venv.html) from Python.org<sup/>

# %%
# !pip install --user ipykernel

# %%
# !python -m ipykernel install --user --name=test

# %% [markdown]
# # **Importing a Package within out Virtual Environment**

# %%
import tensorflow as tf

# %% [markdown]
# # **Removing a Virtual Environment Kernel**

# %%
# !jupyter kernelspec uninstall myenv

# %% [markdown]
# # **References and Additional Learning**

# %% [markdown]
# ## **Article**
#
# - **[Using Virtual Environments in Jupyter Notebook and Python](https://janakiev.com/blog/jupyter-virtual-envs/) by Nikolai Janakiev**

# %% [markdown]
# ## **Websites**
#
# - **[Python Virtual Environments](https://www.marquette.edu/high-performance-computing/py-venv.php) from Marquette University**
#
# - **[venv module](https://docs.python.org/3/library/venv.html) from Python.org**
