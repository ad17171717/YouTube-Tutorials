# %% [markdown]
# <a href="https://colab.research.google.com/github/ad17171717/YouTube-Tutorials/blob/main/Data%20Science%20with%20Python/Sorting%20pandas%20DataFrames/Data_Science_with_Python!_Sorting_pandas_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # **Read the data into a pandas DataFrame**

# %%
df = pd.read_csv('nba_player_stats.csv')
df.head()
# Out:
#                     Player Team   Age    GP     W     L   Min   PTS   FGM  \
# 0              Joel Embiid  PHI  29.0  66.0  43.0  23.0  34.6  33.1  11.0
# 1              Luka Doncic  DAL  24.0  66.0  33.0  33.0  36.2  32.4  10.9
# 2           Damian Lillard  POR  32.0  58.0  27.0  31.0  36.3  32.2   9.6
# 3  Shai Gilgeous-Alexander  OKC  24.0  68.0  33.0  35.0  35.5  31.4  10.4
# 4    Giannis Antetokounmpo  MIL  28.0  63.0  47.0  16.0  32.1  31.1  11.2
#
#     FGA  ...   FTA   FT%  OREB  DREB   REB  AST  TOV  STL  BLK   PF
# 0  20.1  ...  11.7  85.7   1.7   8.4  10.2  4.2  3.4  1.0  1.7  3.1
# 1  22.0  ...  10.5  74.2   0.8   7.8   8.6  8.0  3.6  1.4  0.5  2.5
# 2  20.7  ...   9.6  91.4   0.8   4.0   4.8  7.3  3.3  0.9  0.3  1.9
# 3  20.3  ...  10.9  90.5   0.9   4.0   4.8  5.5  2.8  1.6  1.0  2.8
# 4  20.3  ...  12.3  64.5   2.2   9.6  11.8  5.7  3.9  0.8  0.8  3.1
#
# [5 rows x 25 columns]

# %% [markdown]
# # **Sort DataFrame on a Single Column**

# %%
df.sort_values(by='Player')
# Out:
#                      Player Team   Age    GP     W     L   Min   PTS   FGM  \
# 41          Anfernee Simons  POR  24.0  62.0  27.0  35.0  35.0  21.1   7.5
# 16            Anthony Davis  LAL  30.0  56.0  31.0  25.0  34.0  25.9   9.7
# 22          Anthony Edwards  MIN  21.0  79.0  40.0  39.0  36.0  24.6   8.9
# 50        Bogdan Bogdanovic  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 37         Bojan Bogdanovic  DET  34.0  59.0  15.0  44.0  32.1  21.6   7.3
# 30             Bradley Beal  WAS  29.0  50.0  24.0  26.0  33.5  23.2   8.9
# 21           Brandon Ingram  NOP  25.0  45.0  23.0  22.0  34.2  24.7   9.0
# 43              CJ McCollum  NOP  31.0  75.0  38.0  37.0  35.3  20.9   7.8
# 2            Damian Lillard  POR  32.0  58.0  27.0  31.0  36.3  32.2   9.6
# 36           Darius Garland  CLE  23.0  69.0  40.0  29.0  35.5  21.6   7.6
# 19             De'Aaron Fox  SAC  25.0  73.0  44.0  29.0  33.4  25.0   9.3
# ...

# %% [markdown]
# # **Permanently Sort a DataFrame on a Single Column**

# %%
#permenately sort a pandas DataFrame by setting "inplace=True"
df.sort_values(by='Player',inplace=True,ignore_index=True)

# %%
df
# Out:
#                      Player Team   Age    GP     W     L   Min   PTS   FGM  \
# 0           Anfernee Simons  POR  24.0  62.0  27.0  35.0  35.0  21.1   7.5
# 1             Anthony Davis  LAL  30.0  56.0  31.0  25.0  34.0  25.9   9.7
# 2           Anthony Edwards  MIN  21.0  79.0  40.0  39.0  36.0  24.6   8.9
# 3         Bogdan Bogdanovic  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4          Bojan Bogdanovic  DET  34.0  59.0  15.0  44.0  32.1  21.6   7.3
# 5              Bradley Beal  WAS  29.0  50.0  24.0  26.0  33.5  23.2   8.9
# 6            Brandon Ingram  NOP  25.0  45.0  23.0  22.0  34.2  24.7   9.0
# 7               CJ McCollum  NOP  31.0  75.0  38.0  37.0  35.3  20.9   7.8
# 8            Damian Lillard  POR  32.0  58.0  27.0  31.0  36.3  32.2   9.6
# 9            Darius Garland  CLE  23.0  69.0  40.0  29.0  35.5  21.6   7.6
# 10             De'Aaron Fox  SAC  25.0  73.0  44.0  29.0  33.4  25.0   9.3
# ...

# %% [markdown]
# # **Sort DataFrame on Multiple Columns**

# %%
df.sort_values(by=['Team','Player'])
# Out:
#                      Player Team   Age    GP     W     L   Min   PTS   FGM  \
# 12          Dejounte Murray  ATL  26.0  74.0  38.0  36.0  36.4  20.5   8.3
# 47               Trae Young  ATL  24.0  73.0  38.0  35.0  34.8  26.2   8.2
# 21             Jaylen Brown  BOS  26.0  67.0  46.0  21.0  35.9  26.6  10.1
# 22             Jayson Tatum  BOS  25.0  74.0  52.0  22.0  36.9  30.1   9.8
# 37              LaMelo Ball  CHA  21.0  36.0  13.0  23.0  35.2  23.3   8.2
# 46             Terry Rozier  CHA  29.0  63.0  19.0  44.0  35.3  21.1   7.8
# 11            DeMar DeRozan  CHI  33.0  74.0  37.0  37.0  36.2  24.5   8.9
# 49              Zach LaVine  CHI  28.0  77.0  38.0  39.0  35.9  24.8   8.7
# 9            Darius Garland  CLE  23.0  69.0  40.0  29.0  35.5  21.6   7.6
# 15         Donovan Mitchell  CLE  26.0  68.0  44.0  24.0  35.8  28.3  10.0
# 36             Kyrie Irving  DAL  31.0  60.0  32.0  28.0  37.3  27.1   9.9
# ...

# %% [markdown]
# # **Sort DataFrame in Descending Order**

# %%
df.sort_values(by=['Player'],ascending=False)
# Out:
#                      Player Team   Age    GP     W     L   Min   PTS   FGM  \
# 50          Zion Williamson  NOP  22.0  29.0  17.0  12.0  33.0  26.0   9.8
# 49              Zach LaVine  CHI  28.0  77.0  38.0  39.0  35.9  24.8   8.7
# 48        Tyrese Haliburton  IND  23.0  56.0  28.0  28.0  33.6  20.7   7.4
# 47               Trae Young  ATL  24.0  73.0  38.0  35.0  34.8  26.2   8.2
# 46             Terry Rozier  CHA  29.0  63.0  19.0  44.0  35.3  21.1   7.8
# 45            Stephen Curry  GSW  35.0  56.0  30.0  26.0  34.7  29.4  10.0
# 44  Shai Gilgeous-Alexander  OKC  24.0  68.0  33.0  35.0  35.5  31.4  10.4
# 43              Paul George  LAC  33.0  56.0  32.0  24.0  34.6  23.8   8.2
# 42            Pascal Siakam  TOR  29.0  71.0  35.0  36.0  37.4  24.2   8.9
# 41             Nikola Jokic  DEN  28.0  69.0  48.0  21.0  33.7  24.5   9.4
# 40              Luka Doncic  DAL  24.0  66.0  33.0  33.0  36.2  32.4  10.9
# ...

# %% [markdown]
# # **Position Null Values on Sort**

# %%
df.sort_values(by=['Team'], na_position='last')
# Out:
#                      Player Team   Age    GP     W     L   Min   PTS   FGM  \
# 12          Dejounte Murray  ATL  26.0  74.0  38.0  36.0  36.4  20.5   8.3
# 47               Trae Young  ATL  24.0  73.0  38.0  35.0  34.8  26.2   8.2
# 22             Jayson Tatum  BOS  25.0  74.0  52.0  22.0  36.9  30.1   9.8
# 21             Jaylen Brown  BOS  26.0  67.0  46.0  21.0  35.9  26.6  10.1
# 37              LaMelo Ball  CHA  21.0  36.0  13.0  23.0  35.2  23.3   8.2
# 46             Terry Rozier  CHA  29.0  63.0  19.0  44.0  35.3  21.1   7.8
# 49              Zach LaVine  CHI  28.0  77.0  38.0  39.0  35.9  24.8   8.7
# 11            DeMar DeRozan  CHI  33.0  74.0  37.0  37.0  36.2  24.5   8.9
# 15         Donovan Mitchell  CLE  26.0  68.0  44.0  24.0  35.8  28.3  10.0
# 9            Darius Garland  CLE  23.0  69.0  40.0  29.0  35.5  21.6   7.6
# 40              Luka Doncic  DAL  24.0  66.0  33.0  33.0  36.2  32.4  10.9
# ...

# %% [markdown]
# # **Sort DataFrame on Key**

# %%
df.sort_values(by='Player', key=lambda name: name.str.len())
# Out:
#                      Player Team   Age    GP     W     L   Min   PTS   FGM  \
# 17                Ja Morant  MEM  23.0  61.0  40.0  21.0  31.9  26.2   9.3
# 35               Kyle Kuzma  WAS  27.0  64.0  29.0  35.0  35.0  21.2   8.0
# 47               Trae Young  ATL  24.0  73.0  38.0  35.0  34.8  26.2   8.2
# 25              Joel Embiid  PHI  29.0  66.0  43.0  23.0  34.6  33.1  11.0
# 40              Luka Doncic  DAL  24.0  66.0  33.0  33.0  36.2  32.4  10.9
# 49              Zach LaVine  CHI  28.0  77.0  38.0  39.0  35.9  24.8   8.7
# 19              Jalen Green  HOU  21.0  76.0  20.0  56.0  34.2  22.1   7.4
# 43              Paul George  LAC  33.0  56.0  32.0  24.0  34.6  23.8   8.2
# 37              LaMelo Ball  CHA  21.0  36.0  13.0  23.0  35.2  23.3   8.2
# 7               CJ McCollum  NOP  31.0  75.0  38.0  37.0  35.3  20.9   7.8
# 23             Jerami Grant  POR  29.0  63.0  28.0  35.0  35.6  20.5   6.9
# ...

# %% [markdown]
# # **References and Additional Learning**

# %% [markdown]
# ## **Documentation**
#
# - **[pandas sort_values function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html) from pandas.pydata.org**

# %% [markdown]
# # **Connect**
# - **Feel free to connect with Adrian on [YouTube](https://www.youtube.com/channel/UCPuDxI3xb_ryUUMfkm0jsRA), [LinkedIn](https://www.linkedin.com/in/adrian-dolinay-frm-96a289106/), [Twitter](https://twitter.com/DolinayG), [GitHub](https://github.com/ad17171717), [Medium](https://adriandolinay.medium.com/) and [Odysee](https://odysee.com/@adriandolinay:0). Happy coding!**
