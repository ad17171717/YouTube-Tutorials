# %% [markdown]
# <a href="https://colab.research.google.com/github/ad17171717/YouTube-Tutorials/blob/main/Google%20Colab%20Tutorials/Google_Colab_Downloading_Data_and_Files_to_your_Local_Computer!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %%
data = yf.download("SPY AAPL", start="2020-01-01", end="2023-06-24")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data
# Out:
#              Adj Close                   Close                    High  \
#                   AAPL         SPY        AAPL         SPY        AAPL
# Date
# 2020-01-02   73.347939  307.375671   75.087502  324.869995   75.150002
# 2020-01-03   72.634857  305.048187   74.357498  322.410004   75.144997
# 2020-01-06   73.213608  306.211884   74.949997  323.640015   74.989998
# 2020-01-07   72.869293  305.350922   74.597504  322.730011   75.224998
# 2020-01-08   74.041496  306.978302   75.797501  324.450012   76.110001
# ...                ...         ...         ...         ...         ...
# 2023-06-16  184.919998  439.459991  184.919998  439.459991  186.990005
# 2023-06-20  185.009995  437.179993  185.009995  437.179993  186.100006
# 2023-06-21  183.960007  434.940002  183.960007  434.940002  185.410004
# 2023-06-22  187.000000  436.510010  187.000000  436.510010  187.050003
# 2023-06-23  186.679993  433.209991  186.679993  433.209991  187.559998
#
# ...

# %%
data.to_excel('stock_data.xlsx')

# %% [markdown]
# # **Connect**
# - **Feel free to connect with Adrian on [YouTube](https://www.youtube.com/channel/UCPuDxI3xb_ryUUMfkm0jsRA), [LinkedIn](https://www.linkedin.com/in/adrian-dolinay-frm-96a289106/), [Twitter](https://twitter.com/DolinayG), [GitHub](https://github.com/ad17171717), [Medium](https://adriandolinay.medium.com/) and [Odysee](https://odysee.com/@adriandolinay:0). Happy coding!**
