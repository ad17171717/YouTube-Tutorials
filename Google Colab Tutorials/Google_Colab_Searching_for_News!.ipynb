# %%
# !pip install newsapi-python
from newsapi import NewsApiClient

from IPython.display import IFrame,clear_output
clear_output()

# %% [markdown]
# # **News API**
#
# **News API is a simple HTTP REST API for searching and retrieving live articles from all over the web. You can search for articles with any combination of the following criteria:**
#
# - **Keyword or phrase- Eg: find all articles containing the word 'Microsoft'**
#
#
# - **Date published- Eg: find all articles published yesterday**
#
#
# - **Source domain name- Eg: find all articles published on thenextweb.com**
#
#
# - **Language- Eg: find all articles written in Spanish**

# %% [markdown]
# <sup><sup/>
# Souce: [News API](https://newsapi.org/docs) Documentation

# %% [markdown]
# ## **API Token**
#
# **In order to use News API you need to register with the site and get an API token. You can follow the link [here](https://newsapi.org/register).**

# %%
api_key = input('Input your API Key (as with all keys keep it secret)\n')

api = NewsApiClient(api_key=api_key)

# %% [markdown]
# # **Searching Across All Articles**
#
# **The `get_everything` functions returns all available articles relevant to the given search term. The function returns a nested dictionary and lists out various attributes for the article including: `author`, `content`, `description`, `publishedAt` (date published), `source`, `title`, `URL` and `urlToImage`. Note that the `content` of the article is truncated to 200 characters. If you want to read the full article you can click the URL to read from the source webpage or create a webcrawler to scrape the data and print it out within your environment.**

# %% [markdown]
# <sup><sup/>
# Souce: [News API](https://newsapi.org/docs) Documentation

# %%
api.get_everything(q='gpu')
# Out:
# {'articles': [{'author': 'Steve Dent',
#    'content': "Apple's 2021 MacBook Pros offer incredible performance thanks to the latest M1 Pro and Max chips, while the return of certain key ports makes them more practical than ever. If you've been looking for… [+1654 chars]",
#    'description': "Apple's 2021 MacBook Pros offer incredible performance thanks to the latest M1 Pro and Max chips, while the return of certain key ports makes them more practical than ever. If you've been looking for one but have been put off by the price, the 14-inch 1TB mod…",
#    'publishedAt': '2022-02-23T10:10:39Z',
#    'source': {'id': 'engadget', 'name': 'Engadget'},
#    'title': 'Apple’s 1TB 14-inch MacBook Pro falls to a new all-time low',
#    'url': 'https://www.engadget.com/apples-1-tb-14-inch-mac-book-pro-falls-to-a-new-all-time-low-101039991.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2022-02/f38b1670-9486-11ec-aeb2-4c4742d59d8a'},
#   {'author': 'Tom Warren',
#    'content': 'Nvidia is still officially quiet on availability\r\nNvidias RTX 3090 Ti.\r\nImage: Nvidia\r\nNvidia announced its RTX 3090 Ti at CES earlier this year, promising more information by the end of January. Nvi… [+1155 chars]',
#    'description': 'Nvidia is reportedly planning to launch its RTX 3090 Ti GPU on March 29th. Rumors suggest retailers and reviews will be under embargo until the end of the month.',
#    'publishedAt': '2022-03-09T14:44:57Z',
#    'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'title': 'Nvidia’s RTX 3090 Ti will reportedly launch on March 29th',
#    'url': 'https://www.theverge.com/2022/3/9/22968811/nvidia-rtx-3090-ti-launch-date-price-availability-rumors',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/4mFsejHRQBMCIzkhsHZkdpV3jHI=/0x62:1788x998/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23144510/rtx3090Ti.jpg'},
#   {'author': 'Sam Byford',
#    'content': 'Ming-Chi Kuo strongly believes the new Air has an M1\r\nPhoto by Vjeran Pavic / The Verge\r\nTF International Securities analyst Ming-Chi Kuo strongly believes that the upcoming MacBook Air redesign will… [+1274 chars]',
#    'description': 'Analyst Ming-Chi Kuo “strongly believes” that the upcoming MacBook Air redesign will feature an M1 chip, instead of the widely expected “M2” upgrade. The redesigned MacBook Air had previously been reported to have an M2 chip by Bloomberg’s Mark Gurman.',
#    'publishedAt': '2022-03-09T05:58:38Z',
#    'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'title': 'The redesigned MacBook Air might have an M1, not an M2',
#    'url': 'https://www.theverge.com/2022/3/9/22968489/m2-macbook-air-redesign-m1-ming-chi-kuo',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/VLyTECj67PbeQ0Doj3ieyG3KNZA=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22046475/vpavic_4291_20201113_0380.0.jpg'},
#   {'author': 'Kyle Orland',
#    'content': '5 with 4 posters participating\r\n<ul><li>Cyberpunk 2077, patch 1.5, PlayStation 5, ray-tracing mode. \r\n</li><li>\r\n The same moment in Cyberpunk 2077, patch 1.5, PlayStation 5, performance mode. Notice… [+4949 chars]',
#    'description': 'Special hardware units handle ray traversal, freeing up the GPU shaders.',
#    'publishedAt': '2022-02-28T20:35:37Z',
#    'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'title': 'Sony patents method for “significant improvement of ray tracing speed”',
#    'url': 'https://arstechnica.com/gaming/2022/02/how-sonys-new-patent-filing-could-speed-up-playstation-ray-tracing/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2022/02/Cyberpunk-2077_20220215094154-760x380.jpg'},
#   {'author': 'Igor Bonifacic',
#    'content': 'Some of Samsungs confidential data has reportedly leaked due to a suspected cyberattack. On Friday, South American hacking group Lapsus$ uploaded a trove of data it claims came from the smartphone ma… [+1260 chars]',
#    'description': 'Some of Samsung’s confidential data has reportedly leaked due to a suspected cyberattack. On Friday, South American hacking group Lapsus$ uploaded a trove of data it claims came from the smartphone manufacturer. Bleeping Computer\r\n was among the first publica…',
#    'publishedAt': '2022-03-05T18:15:17Z',
#    'source': {'id': 'engadget', 'name': 'Engadget'},
#    'title': 'Hackers may have obtained 190GB of sensitive data from Samsung',
#    'url': 'https://www.engadget.com/samsung-lapsus-leak-181517961.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2022-03/352faed0-9caf-11ec-beee-051465808cb8'},
#   {'author': 'Khamosh Pathak',
#    'content': 'Microsoft Edge is a pretty good default browser. Now that its made on the same platform as Chrome, its fast, versatile, and efficient; Microsoft has put in a lot of effort to make Edge less resource-… [+1821 chars]',
#    'description': 'Microsoft Edge is a pretty good default browser. Now that it’s made on the same platform as Chrome, it’s fast, versatile, and efficient; Microsoft has put in a lot of effort to make Edge less resource-intensive when compared to Chrome. But for some computers …',
#    'publishedAt': '2022-03-17T15:30:00Z',
#    'source': {'id': None, 'name': 'Lifehacker.com'},
#    'title': "What Is Microsoft Edge's Efficiency Mode (and How Can You Enable It)?",
#    'url': 'https://lifehacker.com/what-is-microsoft-edges-efficiency-mode-and-how-can-yo-1848666190',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/dff3336e1fb741085e67b1db08dee8c2.jpg'},
#   {'author': 'Valentina Palladino',
#    'content': "If you missed the sale earlier this month, now's your chance to grab Apple's Mac Mini M1 at its best price yet. The compact desktop has returned to a record low of $570, thanks to a discount and a co… [+1708 chars]",
#    'description': "If you missed the sale earlier this month, now's your chance to grab Apple's Mac Mini M1 at its best price yet. The compact desktop has returned to a record low of $570, thanks to a discount and a coupon that knocks an additional $80 off the sale price. You'l…",
#    'publishedAt': '2022-03-01T13:50:02Z',
#    'source': {'id': 'engadget', 'name': 'Engadget'},
#    'title': "Apple's Mac Mini M1 drops back down to an all-time low of $570",
#    'url': 'https://www.engadget.com/apples-mac-mini-m1-drops-back-down-to-an-all-time-low-of-570-135002983.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2020-08/b90d6ba0-e088-11ea-bf7d-559c3cbc732c'},
#   {'author': 'Juli Clover',
#    'content': 'Following the launch of the new Mac Studio with M1 Ultra chip, AMD today announced that it has introduced the AMD Radeon PRO W6600X GPU for the existing Intel-based Mac Pro lineup.\r\nThe AMD Radeon PR… [+746 chars]',
#    'description': "Following the launch of the new Mac Studio with M1 Ultra chip, AMD today announced that it has introduced the AMD Radeon PRO W6600X GPU for the existing Intel-based Mac Pro lineup.\n\n\n\n\n\nThe AMD Radeon PRO W6600X GPU is built on AMD's RDNA 2 architecture, whic…",
#    'publishedAt': '2022-03-08T20:35:06Z',
#    'source': {'id': None, 'name': 'MacRumors'},
#    'title': 'Mac Pro Gains New AMD Radeon PRO W6600X GPU Upgrade Option',
#    'url': 'https://www.macrumors.com/2022/03/08/mac-pro-amd-w6600x-gpu/',
#    'urlToImage': 'https://images.macrumors.com/t/5duwSr5u7rwMklyuny4YJ52Tfkw=/1750x/article-new/2022/03/mac-pro-amd-gpu.jpg'},
#   {'author': 'Raymond Hicks',
#    'content': 'Did you miss a session at the Data Summit? Watch On-Demand Here.\r\nWhen Nvidias GTC conference kicks off this week, the sessions will be filled with some of the typical discussions on technical topics… [+5678 chars]',
#    'description': '<ol><li>GTC 2022: GPU topics go beyond tech prowess and applications\xa0\xa0The Madison Leader Gazette\r\n</li><li>NVIDIA Hopper GPU Architecture and H100 Accelerator Announced: Working Smarter and Harder\xa0\xa0AnandTech\r\n</li><li>Nvidia reveals H100 GPU for AI and teases…',
#    'publishedAt': '2022-03-21T19:39:51Z',
#    'source': {'id': None, 'name': 'Wmleader.com'},
#    'title': 'GTC 2022: GPU topics go beyond tech prowess and applications - The Madison Leader Gazette',
#    'url': 'https://wmleader.com/technology/385222/gtc-2022-gpu-topics-go-beyond-tech-prowess-and-applications/',
#    'urlToImage': None},
#   {'author': 'Peter Wayner',
#    'content': 'Did you miss a session at the Data Summit? Watch On-Demand Here.\r\nWhen Nvidias GTC conference kicks off this week, the sessions will be filled with some of the typical discussions on technical topics… [+5678 chars]',
#    'description': 'GPUs were once only noticed by gamers and AI scientists, but they are now key components in many of the most essential parts of the economy. GPUs are the highest-profile circuits sold at the highest prices and are of flagship for the entire industry. When the…',
#    'publishedAt': '2022-03-21T10:30:00Z',
#    'source': {'id': None, 'name': 'VentureBeat'},
#    'title': 'GTC 2020: GPU topics go beyond tech prowess and applications',
#    'url': 'https://venturebeat.com/2022/03/21/gtc-2020-gpu-topics-go-beyond-tech-prowess-and-applications/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2022/03/GPU_circuit_board.jpg?w=1200&strip=all'},
#   {'author': 'Chris J. Preimesberger, Zeus Kerravala',
#    'content': 'Did you miss a session at the Data Summit? Watch On-Demand Here.\r\nFollow VentureBeats ongoing coverage of Nvidias GTC 2022. &gt;&gt;\r\nNvidia packed about three years worth of news into its GPU Techno… [+7453 chars]',
#    'description': "NVIDIA's CEO Jensen Huang's 1 hour, 39-minute keynote covered a lot of ground but the unifying themes to the majority of the two dozen announcements were GPU-centered, and its platform approach to everything it builds.",
#    'publishedAt': '2022-03-22T20:17:48Z',
#    'source': {'id': None, 'name': 'VentureBeat'},
#    'title': 'GTC 2022: NVIDIA flexes its GPU and platform muscles',
#    'url': 'https://venturebeat.com/2022/03/22/gtc-2022-nvidia-flexes-its-gpu-and-platform-muscles/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2022/03/nvidia.jpg?w=1200&strip=all'},
#   {'author': 'Asha Barbaschow',
#    'content': 'Lenovo has released a new range of laptops it says are perfect for younger or new gamers entering the world of gaming they also wouldnt be terrible portable machines for more casual play, with a max … [+4151 chars]',
#    'description': 'Lenovo has released a new range of laptops it says are perfect for “younger” or “new” gamers entering the world of gaming – they also wouldn’t be terrible portable machines for more casual play, with a max weight of 2.5 kgs.Read more...',
#    'publishedAt': '2022-03-04T21:17:00Z',
#    'source': {'id': None, 'name': 'Gizmodo.com'},
#    'title': 'Lenovo Unveils New Range of Portable Machines for More Casual Gamers',
#    'url': 'https://gizmodo.com/lenovo-unveils-new-range-of-portable-machines-for-more-1848613999',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/968c6c69b277b486f745478c3bb4e847.png'},
#   {'author': None,
#    'content': 'Recently piet-gpu has taken a big step towards realizing its vision, moving the computation of path clipping from partially being done on the CPU to entirely being done on the GPU.\r\nThis post explain… [+14065 chars]',
#    'description': 'Recently piet-gpu has taken a big step towards realizing its vision, moving the computation of path clipping from partially being done on the CPU to entirely being done on the GPU.',
#    'publishedAt': '2022-02-25T00:34:06Z',
#    'source': {'id': None, 'name': 'Github.io'},
#    'title': 'Piet-GPU Progress: Clipping',
#    'url': 'https://raphlinus.github.io/rust/graphics/gpu/2022/02/24/piet-gpu-clipping.html',
#    'urlToImage': None},
#   {'author': 'Monica Chin',
#    'content': 'If you buy something from a Verge link, Vox Media may earn a commission. See our ethics statement.The XPS 15 is still loud, still hot, and still good. \r\nIt is not as powerful, and it is not as effici… [+9643 chars]',
#    'description': 'Loud, hot, but OLED it’s got.',
#    'publishedAt': '2022-03-03T13:00:00Z',
#    'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'title': 'Dell XPS 15 review: too hot to handle',
#    'url': 'https://www.theverge.com/22958468/dell-xps-15-2021-oled-review',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/r3qNRsTMkY07qy0qXtA4wS2SRfA=/0x242:2040x1310/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22964107/akrales_211015_4758_0067.jpg'},
#   {'author': 'Juli Clover',
#    'content': "The newly announced M1 Ultra is now Apple's fastest Apple silicon chip, unseating the M1 Max as the top-of-the-line option. With the power of the updated chip, the new Mac Studio is able to outperfor… [+1552 chars]",
#    'description': "The newly announced M1 Ultra is now Apple's fastest Apple silicon chip, unseating the M1 Max as the top-of-the-line option. With the power of the updated chip, the new Mac Studio is able to outperform not only the high-end prior-generation 27-inch iMac, but a…",
#    'publishedAt': '2022-03-08T21:46:12Z',
#    'source': {'id': None, 'name': 'MacRumors'},
#    'title': 'M1 Ultra CPU is 60% Faster Than 28-core Mac Pro, GPU is 80% Faster Than Highest-End Radeon Pro W6900X Graphics Card',
#    'url': 'https://www.macrumors.com/2022/03/08/m1-ultra-cpu-mac-pro-comparison/',
#    'urlToImage': 'https://images.macrumors.com/t/j-JZt9V26x-8w7D5uUBapAtbwZA=/2000x/article-new/2022/03/mac-studio-ultra-performance-gpu.jpg'},
#   {'author': 'Sami Fathi',
#    'content': 'Apple today announced the M1 Ultra chip, the third iteration to the \u200cM1\u200c family, and it represents the next "breakthrough" for Apple Silicon.\r\n\u200cM1\u200c Ultra consists of two M1 Max chips connected with d… [+2030 chars]',
#    'description': 'Apple today announced the M1 Ultra chip, the third iteration to the \u200cM1\u200c family, and it represents the next "breakthrough" for Apple Silicon.\n\n\n\n\n\n\u200cM1\u200c Ultra consists of two M1 Max chips connected with die-to-die technology called "UltraFusion." The new highe…',
#    'publishedAt': '2022-03-08T18:28:38Z',
#    'source': {'id': None, 'name': 'MacRumors'},
#    'title': "Apple Announces 'M1 Ultra' Chip With 20-Core CPU, 64-Core GPU, and Support for 128GB of Memory",
#    'url': 'https://www.macrumors.com/2022/03/08/apple-announces-m1-ultra-chip/',
#    'urlToImage': 'https://images.macrumors.com/t/rohn1FiGVm8iWo0I_dHGYVFJWpM=/1600x/article-new/2022/03/f1646764298.jpg'},
#   {'author': 'Adam Speight',
#    'content': "Rounding things out for Huawei is the MateStation X, an all-in-one with serious iMac vibes. There's no dedicated GPU, just an AMD mobile chip, putting it in competition with the latest colorful M1 Ma… [+2627 chars]",
#    'description': 'Laptops and 2-in-1 devices were out in force at the Mobile World Congress convention in Barcelona. And they stole the show.',
#    'publishedAt': '2022-03-01T12:00:00Z',
#    'source': {'id': 'wired', 'name': 'Wired'},
#    'title': 'The Most Intriguing Launches at MWC 2022 Weren’t Phones',
#    'url': 'https://www.wired.com/story/mwc-2022-laptops-tablets-other-surprises/',
#    'urlToImage': 'https://media.wired.com/photos/621d5b1421173ec112219166/191:100/w_1280,c_limit/Gear-TCL-NXTPAPER-MAX10-SOURCE-TCL.jpg'},
#   {'author': 'Monica Chin',
#    'content': 'It starts at 2.3 pounds\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethics statement.\r\nHeres the keyboard/\r\nImage: Dynabook\r\nDynabook has announced its newest 14… [+2990 chars]',
#    'description': 'The Dynabook Portégé X40L-K is a new 2.3-pound 14-inch laptop powered by 12th-Gen Intel chips. It launches in April and will start at $1,799.99.',
#    'publishedAt': '2022-03-03T13:00:00Z',
#    'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'title': 'Dynabook’s new Portégé will be one of the lightest laptops you can buy',
#    'url': 'https://www.theverge.com/2022/3/3/22958980/dynabook-portege-x40l-k-laptop-prirce-release-date-specs',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/ue-fAY260PSAvuJIjXhVn9bidQA=/0x430:6000x3571/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23284099/Portege_X40LK_00005.png'},
#   {'author': 'EditorDavid',
#    'content': 'Tom\'s Guide tested a Mac Studio workstation equipped with an M1 Ultra with the Geekbench 5.4 CPU benchmarks "to get a sense of how effectively it handles single-core and multi-core workflows.""Since … [+3315 chars]',
#    'description': 'Tom\'s Guide tested a Mac Studio workstation equipped with an M1 Ultra with the Geekbench 5.4 CPU benchmarks "to get a sense of how effectively it handles single-core and multi-core workflows." \n\n"Since our M1 Ultra is the best you can buy (at a rough price of…',
#    'publishedAt': '2022-03-20T01:34:00Z',
#    'source': {'id': None, 'name': 'Slashdot.org'},
#    'title': "More Apple M1 Ultra Benchmarks Show It Doesn't Beat the Best GPUs from Nvidia and AMD",
#    'url': 'https://hardware.slashdot.org/story/22/03/19/2031214/more-apple-m1-ultra-benchmarks-show-it-doesnt-beat-the-best-gpus-from-nvidia-and-amd',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/graphics_64.png'},
#   {'author': None,
#    'content': 'Introduction\r\nWhat is Vast.ai?\r\nVast.ai is a cloud computing, matchmaking and aggregation service focused on lowering the price of compute-intensive workloads.\r\n Our software allows anyone to easily … [+22123 chars]',
#    'description': 'Vast.ai FAQ',
#    'publishedAt': '2022-03-19T18:42:48Z',
#    'source': {'id': None, 'name': 'Vast.ai'},
#    'title': "Vast.ai – marketplace for renting out your GPU, or renting someone else's GPU",
#    'url': 'https://vast.ai/faq/',
#    'urlToImage': 'https://cdn.vast.ai/static/screenshot_generic.png?c=1647827679'}],
#  'status': 'ok',
#  'totalResults': 9889}

# %%
search = input('Input the search topic\n')

for article,idx in zip(api.get_everything(q=search)['articles'],range(len(api.get_everything(q='3d printing')['articles']))):
  print(f'Article {idx}\n','Title:',article['title'],'\n','Author:',article['author'],'\n','Description:',article['description'],'\n','URL:',article['url'],'\n\n\n')
# Out:
# Input the search topic
# gpu
# Article 0
#  Title: Apple’s 1TB 14-inch MacBook Pro falls to a new all-time low
#  Author: Steve Dent
#  Description: Apple's 2021 MacBook Pros offer incredible performance thanks to the latest M1 Pro and Max chips, while the return of certain key ports makes them more practical than ever. If you've been looking for one but have been put off by the price, the 14-inch 1TB mod…
#  URL: https://www.engadget.com/apples-1-tb-14-inch-mac-book-pro-falls-to-a-new-all-time-low-101039991.html
#
#
#
# Article 1
#  Title: Nvidia’s RTX 3090 Ti will reportedly launch on March 29th
#  Author: Tom Warren
#  Description: Nvidia is reportedly planning to launch its RTX 3090 Ti GPU on March 29th. Rumors suggest retailers and reviews will be under embargo until the end of the month.
#  URL: https://www.theverge.com/2022/3/9/22968811/nvidia-rtx-3090-ti-launch-date-price-availability-rumors
#
#
#
# Article 2
#  Title: The redesigned MacBook Air might have an M1, not an M2
#  Author: Sam Byford
#  Description: Analyst Ming-Chi Kuo “strongly believes” that the upcoming MacBook Air redesign will feature an M1 chip, instead of the widely expected “M2” upgrade. The redesigned MacBook Air had previously been reported to have an M2 chip by Bloomberg’s Mark Gurman.
#  URL: https://www.theverge.com/2022/3/9/22968489/m2-macbook-air-redesign-m1-ming-chi-kuo
#
#
#
# Article 3
#  Title: Sony patents method for “significant improvement of ray tracing speed”
#  Author: Kyle Orland
#  Description: Special hardware units handle ray traversal, freeing up the GPU shaders.
#  URL: https://arstechnica.com/gaming/2022/02/how-sonys-new-patent-filing-could-speed-up-playstation-ray-tracing/
#
#
#
# Article 4
#  Title: Hackers may have obtained 190GB of sensitive data from Samsung
#  Author: Igor Bonifacic
#  Description: Some of Samsung’s confidential data has reportedly leaked due to a suspected cyberattack. On Friday, South American hacking group Lapsus$ uploaded a trove of data it claims came from the smartphone manufacturer. Bleeping Computer
#  was among the first publica…
#  URL: https://www.engadget.com/samsung-lapsus-leak-181517961.html
#
#
#
# Article 5
#  Title: What Is Microsoft Edge's Efficiency Mode (and How Can You Enable It)?
#  Author: Khamosh Pathak
#  Description: Microsoft Edge is a pretty good default browser. Now that it’s made on the same platform as Chrome, it’s fast, versatile, and efficient; Microsoft has put in a lot of effort to make Edge less resource-intensive when compared to Chrome. But for some computers …
#  URL: https://lifehacker.com/what-is-microsoft-edges-efficiency-mode-and-how-can-yo-1848666190
#
#
#
# Article 6
#  Title: Apple's Mac Mini M1 drops back down to an all-time low of $570
#  Author: Valentina Palladino
#  Description: If you missed the sale earlier this month, now's your chance to grab Apple's Mac Mini M1 at its best price yet. The compact desktop has returned to a record low of $570, thanks to a discount and a coupon that knocks an additional $80 off the sale price. You'l…
#  URL: https://www.engadget.com/apples-mac-mini-m1-drops-back-down-to-an-all-time-low-of-570-135002983.html
#
#
#
# Article 7
#  Title: Mac Pro Gains New AMD Radeon PRO W6600X GPU Upgrade Option
#  Author: Juli Clover
#  Description: Following the launch of the new Mac Studio with M1 Ultra chip, AMD today announced that it has introduced the AMD Radeon PRO W6600X GPU for the existing Intel-based Mac Pro lineup.
#
#
#
#
#
# The AMD Radeon PRO W6600X GPU is built on AMD's RDNA 2 architecture, whic…
#  URL: https://www.macrumors.com/2022/03/08/mac-pro-amd-w6600x-gpu/
#
#
#
# Article 8
#  Title: GTC 2022: GPU topics go beyond tech prowess and applications - The Madison Leader Gazette
#  Author: Raymond Hicks
#  Description: <ol><li>GTC 2022: GPU topics go beyond tech prowess and applications  The Madison Leader Gazette
# </li><li>NVIDIA Hopper GPU Architecture and H100 Accelerator Announced: Working Smarter and Harder  AnandTech
# </li><li>Nvidia reveals H100 GPU for AI and teases…
#  URL: https://wmleader.com/technology/385222/gtc-2022-gpu-topics-go-beyond-tech-prowess-and-applications/
#
#
#
# Article 9
#  Title: GTC 2020: GPU topics go beyond tech prowess and applications
#  Author: Peter Wayner
#  Description: GPUs were once only noticed by gamers and AI scientists, but they are now key components in many of the most essential parts of the economy. GPUs are the highest-profile circuits sold at the highest prices and are of flagship for the entire industry. When the…
#  URL: https://venturebeat.com/2022/03/21/gtc-2020-gpu-topics-go-beyond-tech-prowess-and-applications/
#
#
#
# Article 10
#  Title: GTC 2022: NVIDIA flexes its GPU and platform muscles
#  Author: Chris J. Preimesberger, Zeus Kerravala
#  Description: NVIDIA's CEO Jensen Huang's 1 hour, 39-minute keynote covered a lot of ground but the unifying themes to the majority of the two dozen announcements were GPU-centered, and its platform approach to everything it builds.
#  URL: https://venturebeat.com/2022/03/22/gtc-2022-nvidia-flexes-its-gpu-and-platform-muscles/
#
#
#
# Article 11
#  Title: Lenovo Unveils New Range of Portable Machines for More Casual Gamers
#  Author: Asha Barbaschow
#  Description: Lenovo has released a new range of laptops it says are perfect for “younger” or “new” gamers entering the world of gaming – they also wouldn’t be terrible portable machines for more casual play, with a max weight of 2.5 kgs.Read more...
#  URL: https://gizmodo.com/lenovo-unveils-new-range-of-portable-machines-for-more-1848613999
#
#
#
# Article 12
#  Title: Piet-GPU Progress: Clipping
#  Author: None
#  Description: Recently piet-gpu has taken a big step towards realizing its vision, moving the computation of path clipping from partially being done on the CPU to entirely being done on the GPU.
#  URL: https://raphlinus.github.io/rust/graphics/gpu/2022/02/24/piet-gpu-clipping.html
#
#
#
# Article 13
#  Title: Dell XPS 15 review: too hot to handle
#  Author: Monica Chin
#  Description: Loud, hot, but OLED it’s got.
#  URL: https://www.theverge.com/22958468/dell-xps-15-2021-oled-review
#
#
#
# Article 14
#  Title: M1 Ultra CPU is 60% Faster Than 28-core Mac Pro, GPU is 80% Faster Than Highest-End Radeon Pro W6900X Graphics Card
#  Author: Juli Clover
#  Description: The newly announced M1 Ultra is now Apple's fastest Apple silicon chip, unseating the M1 Max as the top-of-the-line option. With the power of the updated chip, the new Mac Studio is able to outperform not only the high-end prior-generation 27-inch iMac, but a…
#  URL: https://www.macrumors.com/2022/03/08/m1-ultra-cpu-mac-pro-comparison/
#
#
#
# Article 15
#  Title: Apple Announces 'M1 Ultra' Chip With 20-Core CPU, 64-Core GPU, and Support for 128GB of Memory
#  Author: Sami Fathi
#  Description: Apple today announced the M1 Ultra chip, the third iteration to the ‌M1‌ family, and it represents the next "breakthrough" for Apple Silicon.
#
#
#
#
#
# ‌M1‌ Ultra consists of two M1 Max chips connected with die-to-die technology called "UltraFusion." The new highe…
#  URL: https://www.macrumors.com/2022/03/08/apple-announces-m1-ultra-chip/
#
#
#
# Article 16
#  Title: The Most Intriguing Launches at MWC 2022 Weren’t Phones
#  Author: Adam Speight
#  Description: Laptops and 2-in-1 devices were out in force at the Mobile World Congress convention in Barcelona. And they stole the show.
#  URL: https://www.wired.com/story/mwc-2022-laptops-tablets-other-surprises/
#
#
#
# Article 17
#  Title: Dynabook’s new Portégé will be one of the lightest laptops you can buy
#  Author: Monica Chin
#  Description: The Dynabook Portégé X40L-K is a new 2.3-pound 14-inch laptop powered by 12th-Gen Intel chips. It launches in April and will start at $1,799.99.
#  URL: https://www.theverge.com/2022/3/3/22958980/dynabook-portege-x40l-k-laptop-prirce-release-date-specs
#
#
#
# Article 18
#  Title: More Apple M1 Ultra Benchmarks Show It Doesn't Beat the Best GPUs from Nvidia and AMD
#  Author: EditorDavid
#  Description: Tom's Guide tested a Mac Studio workstation equipped with an M1 Ultra with the Geekbench 5.4 CPU benchmarks "to get a sense of how effectively it handles single-core and multi-core workflows."
#
# "Since our M1 Ultra is the best you can buy (at a rough price of…
#  URL: https://hardware.slashdot.org/story/22/03/19/2031214/more-apple-m1-ultra-benchmarks-show-it-doesnt-beat-the-best-gpus-from-nvidia-and-amd
#
#
#
# Article 19
#  Title: Vast.ai – marketplace for renting out your GPU, or renting someone else's GPU
#  Author: None
#  Description: Vast.ai FAQ
#  URL: https://vast.ai/faq/

# %%
IFrame(api.get_everything('gpu')['articles'][9]['url'],width=1800, height=1000)

# %% [markdown]
# # **Searching for Top Headlines**
#
# **The `get_top_headlines` function provides live top and breaking headlines for a country, specific category in a country, single source, or multiple sources. You can also search with keywords. Articles are sorted by the earliest date published first.**

# %% [markdown]
# <sup><sup/>
# Souce: [News API](https://newsapi.org/docs) Documentation

# %%
api.get_top_headlines('iphone')
# Out:
# {'articles': [{'author': 'Chaim Gartenberg',
#    'content': 'Basically just a Wi-Fi radio away from being a gigantic iPad\r\nPhoto by Becca Farsace / The Verge\r\nApples new Studio Display is a fascinating piece of technology, largely due to the A13 Bionic chipset… [+1953 chars]',
#    'description': 'Apple’s new Studio Display doesn’t just have an A13 processor: it has 64GB of internal storage, the same as an entry-level iPhone 11. It’s practically a whole computer all by itself.',
#    'publishedAt': '2022-03-22T15:08:05Z',
#    'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'title': "Apple's Studio Display has 64GB of storage in addition to its iPhone 11-caliber processor - The Verge",
#    'url': 'https://www.theverge.com/2022/3/22/22990875/apple-studio-display-64gb-storage-a13-processor-iphone-hardware',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/EgRlpZo2DzreMAejmObSICnI1oE=/0x147:2040x1215/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23320963/bfarsace_171212_5072_0065.jpg'},
#   {'author': 'The Macalope',
#    'content': 'Skip to contentType your search and hit enter\r\nIt is time once again for one of the Macalope’s quarterly paeans to the small iPhone form factor. If small phones aren’t your thing, feel free to read t… [+3903 chars]',
#    'description': "No new iPhone mini this year? Say it isn't so.",
#    'publishedAt': '2022-03-22T12:05:28Z',
#    'source': {'id': None, 'name': 'Macworld'},
#    'title': 'Apple is about to make a big mistake with the iPhone 14 - PC World New Zealand',
#    'url': 'https://www.macworld.com/article/625084/macalope-iphone-mini.html',
#    'urlToImage': 'https://www.macworld.com/wp-content/uploads/2022/03/iphone-12-mini-2.jpg?quality=50&strip=all&w=1024'},
#   {'author': None,
#    'content': 'Whether you are a strong proponent of Right to Repair or love to “DIY” your stuff, there is a good chance you would appreciate the ability to restore a bricked Apple Watch using your iPhone. Yeah, yo… [+6440 chars]',
#    'description': "Restore Apple Watch with iPhone: double click the side button on Apple Watch, tap on 'Continue' in the prompt on your iPhone.",
#    'publishedAt': '2022-03-22T06:18:29Z',
#    'source': {'id': None, 'name': 'Beebom'},
#    'title': 'How to Restore Apple Watch Using Your iPhone - Beebom',
#    'url': 'https://beebom.com/how-restore-apple-watch-with-iphone/',
#    'urlToImage': 'https://beebom.com/wp-content/uploads/2022/03/restore-apple-watch-with-iPhone-featured.jpg'}],
#  'status': 'ok',
#  'totalResults': 3}

# %%
search = input('Input the search topic\n')

for article,idx in zip(api.get_top_headlines(q=search)['articles'],range(len(api.get_everything(q='3d printing')['articles']))):
  print(f'Article {idx}\n','Title:',article['title'],'\n','Author:',article['author'],'\n','Description:',article['description'],'\n','URL:',article['url'],'\n\n\n')
# Out:
# Input the search topic
# iphone
# Article 0
#  Title: Apple's Studio Display has 64GB of storage in addition to its iPhone 11-caliber processor - The Verge
#  Author: Chaim Gartenberg
#  Description: Apple’s new Studio Display doesn’t just have an A13 processor: it has 64GB of internal storage, the same as an entry-level iPhone 11. It’s practically a whole computer all by itself.
#  URL: https://www.theverge.com/2022/3/22/22990875/apple-studio-display-64gb-storage-a13-processor-iphone-hardware
#
#
#
# Article 1
#  Title: Apple is about to make a big mistake with the iPhone 14 - PC World New Zealand
#  Author: The Macalope
#  Description: No new iPhone mini this year? Say it isn't so.
#  URL: https://www.macworld.com/article/625084/macalope-iphone-mini.html
#
#
#
# Article 2
#  Title: How to Restore Apple Watch Using Your iPhone - Beebom
#  Author: None
#  Description: Restore Apple Watch with iPhone: double click the side button on Apple Watch, tap on 'Continue' in the prompt on your iPhone.
#  URL: https://beebom.com/how-restore-apple-watch-with-iphone/

# %%
IFrame(api.get_top_headlines('iphone')['articles'][1]['url'],width=1800, height=1000)
# Out:
#         <iframe
#             width="1800"
#             height="1000"
#             src="https://www.macworld.com/article/625084/macalope-iphone-mini.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # **Searching in Different Languages using the `get_everything` Function**
#
#
# | *Available Language for `get_everything` function  | ISO-639-1 code  |
# |---|---|
# | Arabic  | ar  |
# | German  | de  |
# |  Englsih |  en |
# | Spanish  |  es |
# | French  |  fr |
# | Hebrew  |  he |
# | Italian  |  it |
# | Dutch  |  nl |
# | Norwegian  |  no |
# |  Portuguese |  pt |
# |  Russian |  ru |
# | Chinese  |  zh |
#
# <sup><sup/>
# *Omitted `se` and `ud` because the codes did not return any results

# %% [markdown]
# <sup><sup/>
# Souce: [News API](https://newsapi.org/docs) Documentation

# %%
search = input('Input the search topic\n')


iso_639 = ['ar',	'de',	'en',	'es',	'fr',	'he',	'it',	'nl',	'no',	'pt',	'ru',	'zh']

for lang in iso_639:
  print(f'Language used for search: {lang}')
  for article,idx in zip(api.get_everything(q=search, language=lang)['articles'],range(len(api.get_everything(q='3d printing')['articles']))):
    print(f'Article {idx}\n','Title:',article['title'],'\n','Author:',article['author'],'\n','Description:',article['description'],'\n','URL:',article['url'],'\n\n\n')
# Out:
# Input the search topic
# gpu
# Language used for search: ar
# Article 0
#  Title: لماذا NVIDIA RTX￼￼￼￼ بدلاً من أجهزة الألعاب (الكونسول)؟
#  Author: بيان صحفي
#  Description: تقدم تقنية NVIDIA RTX في أجهزة الكمبيوتر تجربة لعب فريدة واستثنائية بفضل جمعها بين تتبع الضوء والوقت الحقيقي وتقنيات الذكاء الاصطناعي، لتشعر كأنك جزء من لعبة حقيقية بأبعاد سينمائية! في حال كنت تشعر بالحيرة بين اختيار جهاز كمبيوتر PC أو وحدة تحكم لألعاب الفيدي…
#  URL: https://www.tech-wd.com/wd/2022/03/22/%d9%84%d9%85%d8%a7%d8%b0%d8%a7-nvidia-rtx%ef%bf%bc%ef%bf%bc%ef%bf%bc%ef%bf%bc-%d8%a8%d8%af%d9%84%d8%a7%d9%8b-%d9%85%d9%86-%d8%a3%d8%ac%d9%87%d8%b2%d8%a9-%d8%a7%d9%84%d8%a3%d9%84%d8%b9%d8%a7/
#
#
#
# Article 1
#  Title: لماذا NVIDIA RTX بدلاً من أجهزة الألعاب (الكونسول)؟
#  Author: بيان صحفي
#  Description: تقدم تقنية NVIDIA RTX في أجهزة الكمبيوتر تجربة لعب فريدة واستثنائية بفضل جمعها بين تتبع الضوء والوقت الحقيقي وتقنيات الذكاء الاصطناعي، لتشعر كأنك جزء من لعبة حقيقية بأبعاد سينمائية! في حال كنت تشعر بالحيرة بين اختيار جهاز كمبيوتر PC أو وحدة تحكم لألعاب الفيدي…
#  URL: https://www.tech-wd.com/wd/2022/03/22/%d9%84%d9%85%d8%a7%d8%b0%d8%a7-nvidia-rtx-%d8%a8%d8%af%d9%84%d8%a7%d9%8b-%d9%85%d9%86-%d8%a3%d8%ac%d9%87%d8%b2%d8%a9-%d8%a7%d9%84%d8%a3%d9%84%d8%b9%d8%a7%d8%a8-%d8%a7%d9%84%d9%83%d9%88/
#
#
#
# Article 2
#  Title: الكشف عن سلسلة Honor Magic 4 مع أندرويد 12 وشحن لاسلكي سريع 100 واط
#  Author: ضياء محمود
#  Description: كشفت شركة هونر عن سلسلة هواتف Honor Magic 4 الراقية على هامش فعاليات MWC 2022، وذلك مع أحدث المواصفات بينها معالج كوالكوم الأخير والشحن السريع 100 واط، فضلًا عن العمل على نظام أندرويد 12. وتأتي السلسلة مع نسخة Honor Magic 4 Pro ونسخة عادية بمواصفات أقل. هاتف …
#  URL: https://www.tech-wd.com/wd/2022/02/28/%d8%a7%d9%84%d9%83%d8%b4%d9%81-%d8%b9%d9%86-%d8%b3%d9%84%d8%b3%d9%84%d8%a9-honor-magic-4-%d9%85%d8%b9-%d8%a3%d9%86%d8%af%d8%b1%d9%88%d9%8a%d8%af-12-%d9%88%d8%b4%d8%ad%d9%86-%d9%84%d8%a7%d8%b3%d9%84/
#
#
#
# Article 3
#  Title: حمى التنقيب عن العملات الرقمية تجتاح شباب العالم
#  Author: محمد سناجلة
#  Description: بلغ حجم التعدين العالمي للعملات الرقمية المشفرة 4050.5 مليون دولار أميركي في عام 2020، ومن المتوقع أن يبلغ 4502.4 مليون دولار في 2026، وهو مؤشر على اتجاه الأفراد نحو تعدين العملات.
#  URL: https://www.aljazeera.net/news/scienceandtechnology/2022/2/23/حمى-التنقيب-عن-العملات-الرقمية-تجتاح
#
#
#
# Language used for search: de
# Article 0
#  Title: Intel holt sich Chef-GPU-Architekten von AMD zurück
#  Author: Mark Mantel
#  Description: Rohit Verma wechselt nach 8 Jahren von AMD zurück nach Intel, wo er als Lead Product Architect maßgeblich an der Entwicklung neuer Grafikkarten beteiligt ist.
#  URL: https://www.heise.de/news/Intel-holt-sich-Chef-GPU-Architekten-von-AMD-zurueck-6518003.html
#
#
#
# Article 1
#  Title: Khronos legt Vulkan-Spezifikation für sicherheitskritische GPU-Beschleuniger vor
#  Author: Matthias Parbel
#  Description: Die Vulkan SC 1.0 API-Spezifikation soll funktionale Sicherheit bei GPU-Anwendungen in regulierten Bereichen wie Medizin oder Luftfahrt gewährleisten.
#  URL: https://www.heise.de/news/Khronos-legt-Vulkan-Spezifikation-fuer-sicherheitskritische-GPU-Beschleuniger-vor-6529658.html
#
#
#
# Article 2
#  Title: MWC: 2022er-ThinkPads: AMD Ryzen 6000 und Intel Core i-1200 mit flottem RAM
#  Author: Mark Mantel
#  Description: Lenovo gibt AMDs Ryzen-6000U-Prozessoren den Speicherturbo: Vom LPDDR5-6400-RAM dürfte insbesondere die Radeon-GPU profitieren.
#  URL: https://www.heise.de/news/2022er-ThinkPads-AMD-Ryzen-6000-und-Intel-Core-i-1200-mit-flottem-RAM-6526840.html
#
#
#
# Article 3
#  Title: Nvidia Hopper: Nächste GPU-Generation mit 80 GByte HBM3-Speicher und 3 TByte/s
#  Author: Martin Fischer
#  Description: Nvidias kommende GPU-Generation Hopper protzt mit hohen Transferraten und viel Speicher – das zielt auf aufwendige KI-Berechnungen und Sprachverarbeitung.
#  URL: https://www.heise.de/news/Nvidia-Hopper-Naechste-GPU-Generation-mit-80-GByte-HBM3-Speicher-und-3-TByte-s-6598382.html
#
#
#
# Article 4
#  Title: Intel-GPUs: Arc A370M erscheint Ende März
#  Author: Mark Mantel
#  Description: (Bis zu) die doppelte Performance verglichen mit den Xe-GPUs der Alder-Lake-Prozessoren verspricht Intel bei der ersten Arc-GPU A370M.
#  URL: https://www.heise.de/news/Intel-GPUs-Arc-A370M-erscheint-Ende-Maerz-6549845.html
#
#
#
# Article 5
#  Title: Cache-Monster: Leaks zu Nvidias nächster Grafikkartengeneration Ada Lovelace
#  Author: Mark Mantel
#  Description: Nvidia soll mit der nächsten GeForce-Baureihe einen ähnlichen Weg einschlagen wie AMD mit den Radeon-GPUs RX 6000: viel Cache zur Entlastung des DRAMs.
#  URL: https://www.heise.de/news/Cache-Monster-Leaks-zu-Nvidias-naechster-Grafikkartengeneration-Ada-Lovelace-6533561.html
#
#
#
# Article 6
#  Title: Nvidia-Hack: Ransomware-Gruppe drohnt mit Mining-Drossel-Aufhebung
#  Author: Marc Sauter
#  Description: Die Erpresser sollen planen, Nvidias Crypto-Mining-Bremse auszuhebeln. Zudem gibt es Informationen zu kommenden GPU-Generationen. (Nvidia, Virtualisierung)
#  URL: https://www.golem.de/sonstiges/zustimmung/auswahl.html?from=https%3A%2F%2Fwww.golem.de%2Fnews%2Fnvidia-hack-ransomware-gruppe-drohnt-mit-mining-drossel-aufhebung-2203-163508-rss.html&referer=https%3A%2F%2Ft.co%2Fe549466f37
#
#
#
# Article 7
#  Title: Big Accelerator Memory: GPU liest und schreibt direkt auf SSDs
#  Author: Johannes Hiltscher
#  Description: Mit Big Accelerator Memory kommunizieren Nvidias A100-Rechenbeschleuniger mit SSDs. Die GPU kann rechnen, statt zu synchronisieren. (Nvidia, IBM)
#  URL: https://www.golem.de/sonstiges/zustimmung/auswahl.html?from=https%3A%2F%2Fwww.golem.de%2Fnews%2Fbig-accelerator-memory-gpu-liest-und-schreibt-direkt-auf-ssds-2203-163862-rss.html&referer=https%3A%2F%2Ft.co%2Fcf5b51821e
#
#
#
# Article 8
#  Title: Chinesischer Zoll: Tausende Radeon-Grafikkarten beschlagnahmt
#  Author: Mark Mantel
#  Description: Fast 6000 Grafikkarten des Herstellers XFX sollten mit falschen Modellaufklebern durch den Zoll gehen, um Steuern zu hinterziehen.
#  URL: https://www.heise.de/news/Chinesischer-Zoll-Tausende-Radeon-Grafikkarten-beschlagnahmt-6548776.html
#
#
#
# Article 9
#  Title: Neuer Hochleistungsrechner spielt den Klimawandel schneller durch
#  Author: Arne Grävemeyer
#  Description: Mit dem neuen Rechnersystem "Levante" vervierfacht das Deutsche Klima-Rechenzentrum seine Kapazität. Damit kann es nun den Klimawandel exakter vorhersagen.
#  URL: https://www.heise.de/news/Neuer-Hochleistungsrechner-spielt-den-Klimawandel-schneller-durch-6540351.html
#
#
#
# Article 10
#  Title: Neue Prozessorgeneration von Apple: M1 Ultra mit zwei M1 Max
#  Author: Johannes Schuster
#  Description: Das neue Prozessor-Flaggschiff kombiniert zwei der leistungsstarken M1 Max mit einer Die-zu-Die-Verbindung.
#  URL: https://www.heise.de/news/Neue-Prozessorgeneration-von-Apple-M1-Ultra-mit-zwei-M1-Max-6543050.html
#
#
#
# Article 11
#  Title: MWC: PureBook Pro: Die ersten Nokia-Notebooks für Europa
#  Author: Mark Mantel
#  Description: Ein französisches Unternehmen steigt mit der Marke Nokia in den Notebook-Markt ein. Zum Einsatz kommen Intels 10-Kern-Prozessoren.
#  URL: https://www.heise.de/news/PureBook-Pro-Die-ersten-Nokia-Notebooks-fuer-Europa-6522758.html
#
#
#
# Article 12
#  Title: Standard-Schnittstelle UCIe für Chiplet-Mischungen
#  Author: Christof Windeck
#  Description: Um Chiplets unterschiedlicher Hersteller zu einem Prozessor oder Rechenbeschleuniger zu koppeln, dient die mit PCI Express (PCIe) verwandte Schnittstelle UCIe.
#  URL: https://www.heise.de/news/Standard-Schnittstelle-UCIe-fuer-Chiplet-Mischungen-6535218.html
#
#
#
# Article 13
#  Title: AMD-Grafikkarten: Radeon Super Resolution direkt im Treiber, FSR 2.0 folgt
#  Author: Mark Mantel
#  Description: Das bisherige FidelityFX Super Resolution kommt in abgewandelter Form in AMDs Grafiktreiber für alle Spiele. Zudem kündigt AMD FSR 2.0 an.
#  URL: https://www.heise.de/news/AMD-Grafikkarten-Radeon-Super-Resolution-direkt-im-Treiber-FSR-2-0-folgt-6586288.html
#
#
#
# Article 14
#  Title: Bit-Rauschen, der Prozessor-Podcast: Das verspricht der Apple M1 Ultra
#  Author: Christof Windeck
#  Description: Beim ARM-Prozessor M1 Ultra für den Mac Studio geizt Apple nicht mit Superlativen - wir schauen auf die Details im Audio-Podcast Bit-Rauschen, Folge 2022/06.
#  URL: https://www.heise.de/meinung/Bit-Rauschen-der-Prozessor-Podcast-Das-verspricht-der-Apple-M1-Ultra-6533145.html
#
#
#
# Article 15
#  Title: Angeblich bis zu sieben neue Macs für 2022 in der Pipeline
#  Author: Ben Schwan
#  Description: Apple scheint in diesem Jahr zu planen, große Teile seines Rechner-Line-up zu überholen. Betroffen sind sowohl Desktops als auch Notebooks.
#  URL: https://www.heise.de/news/Angeblich-bis-zu-sieben-neue-Macs-fuer-2022-in-der-Pipeline-6513172.html
#
#
#
# Article 16
#  Title: AMD Ryzen: Günstigere Prozessoren gegen Intels "Alder Lake"
#  Author: Mark Mantel
#  Description: Drei neue Modelle sollen endlich AMDs Prozessoraufgebot im Preisbereich von 150 bis 300 Euro aufbessern, darunter ein Ryzen 7 5700X.
#  URL: https://www.heise.de/news/AMD-Ryzen-Guenstigere-Prozessoren-gegen-Intels-Alder-Lake-6541611.html
#
#
#
# Article 17
#  Title: Gerüchte zusammengefasst: Neue Grafikkarten und Prozessoren von März bis Juni
#  Author: Mark Mantel
#  Description: Noch im März 2022 soll Nvidias GeForce RTX 3090 Ti erscheinen, im April folgen neue Radeon-Grafikkarten und günstigere Ryzen-Prozessoren.
#  URL: https://www.heise.de/news/Geruechte-zusammengefasst-Neue-Grafikkarten-und-Prozessoren-von-Maerz-bis-Juni-6546796.html
#
#
#
# Article 18
#  Title: GDC: Unity-Techdemo "Enemies": Diese Frau existiert nicht wirklich
#  Author: Mark Mantel
#  Description: Ein zweiminütiges Video zeigt, wie realistisch die Spiele-Engine Unity virtuelle Menschen rendern kann.
#  URL: https://www.heise.de/news/Unity-Techdemo-Enemies-Diese-Frau-existiert-nicht-wirklich-6603447.html
#
#
#
# Article 19
#  Title: Apple: Neuer Mac Pro mit Apple Silicon im Anflug
#  Author: Ben Schwan
#  Description: Der Konzern hat am Dienstag mitgeteilt, dass er weiterhin an der Workstation arbeitet. Der Mac Studio bleibt also nicht die einzige Profi-Kiste für den Desktop.
#  URL: https://www.heise.de/news/Apple-Neuer-Mac-Pro-mit-Apple-Silicon-im-Anflug-6543717.html
#
#
#
# Language used for search: en
# Article 0
#  Title: Apple’s 1TB 14-inch MacBook Pro falls to a new all-time low
#  Author: Steve Dent
#  Description: Apple's 2021 MacBook Pros offer incredible performance thanks to the latest M1 Pro and Max chips, while the return of certain key ports makes them more practical than ever. If you've been looking for one but have been put off by the price, the 14-inch 1TB mod…
#  URL: https://www.engadget.com/apples-1-tb-14-inch-mac-book-pro-falls-to-a-new-all-time-low-101039991.html
#
#
#
# Article 1
#  Title: Nvidia’s RTX 3090 Ti will reportedly launch on March 29th
#  Author: Tom Warren
#  Description: Nvidia is reportedly planning to launch its RTX 3090 Ti GPU on March 29th. Rumors suggest retailers and reviews will be under embargo until the end of the month.
#  URL: https://www.theverge.com/2022/3/9/22968811/nvidia-rtx-3090-ti-launch-date-price-availability-rumors
#
#
#
# Article 2
#  Title: The redesigned MacBook Air might have an M1, not an M2
#  Author: Sam Byford
#  Description: Analyst Ming-Chi Kuo “strongly believes” that the upcoming MacBook Air redesign will feature an M1 chip, instead of the widely expected “M2” upgrade. The redesigned MacBook Air had previously been reported to have an M2 chip by Bloomberg’s Mark Gurman.
#  URL: https://www.theverge.com/2022/3/9/22968489/m2-macbook-air-redesign-m1-ming-chi-kuo
#
#
#
# Article 3
#  Title: Sony patents method for “significant improvement of ray tracing speed”
#  Author: Kyle Orland
#  Description: Special hardware units handle ray traversal, freeing up the GPU shaders.
#  URL: https://arstechnica.com/gaming/2022/02/how-sonys-new-patent-filing-could-speed-up-playstation-ray-tracing/
#
#
#
# Article 4
#  Title: Hackers may have obtained 190GB of sensitive data from Samsung
#  Author: Igor Bonifacic
#  Description: Some of Samsung’s confidential data has reportedly leaked due to a suspected cyberattack. On Friday, South American hacking group Lapsus$ uploaded a trove of data it claims came from the smartphone manufacturer. Bleeping Computer
#  was among the first publica…
#  URL: https://www.engadget.com/samsung-lapsus-leak-181517961.html
#
#
#
# Article 5
#  Title: What Is Microsoft Edge's Efficiency Mode (and How Can You Enable It)?
#  Author: Khamosh Pathak
#  Description: Microsoft Edge is a pretty good default browser. Now that it’s made on the same platform as Chrome, it’s fast, versatile, and efficient; Microsoft has put in a lot of effort to make Edge less resource-intensive when compared to Chrome. But for some computers …
#  URL: https://lifehacker.com/what-is-microsoft-edges-efficiency-mode-and-how-can-yo-1848666190
#
#
#
# Article 6
#  Title: Apple's Mac Mini M1 drops back down to an all-time low of $570
#  Author: Valentina Palladino
#  Description: If you missed the sale earlier this month, now's your chance to grab Apple's Mac Mini M1 at its best price yet. The compact desktop has returned to a record low of $570, thanks to a discount and a coupon that knocks an additional $80 off the sale price. You'l…
#  URL: https://www.engadget.com/apples-mac-mini-m1-drops-back-down-to-an-all-time-low-of-570-135002983.html
#
#
#
# Article 7
#  Title: Mac Pro Gains New AMD Radeon PRO W6600X GPU Upgrade Option
#  Author: Juli Clover
#  Description: Following the launch of the new Mac Studio with M1 Ultra chip, AMD today announced that it has introduced the AMD Radeon PRO W6600X GPU for the existing Intel-based Mac Pro lineup.
#
#
#
#
#
# The AMD Radeon PRO W6600X GPU is built on AMD's RDNA 2 architecture, whic…
#  URL: https://www.macrumors.com/2022/03/08/mac-pro-amd-w6600x-gpu/
#
#
#
# Article 8
#  Title: GTC 2022: GPU topics go beyond tech prowess and applications - The Madison Leader Gazette
#  Author: Raymond Hicks
#  Description: <ol><li>GTC 2022: GPU topics go beyond tech prowess and applications  The Madison Leader Gazette
# </li><li>NVIDIA Hopper GPU Architecture and H100 Accelerator Announced: Working Smarter and Harder  AnandTech
# </li><li>Nvidia reveals H100 GPU for AI and teases…
#  URL: https://wmleader.com/technology/385222/gtc-2022-gpu-topics-go-beyond-tech-prowess-and-applications/
#
#
#
# Article 9
#  Title: GTC 2020: GPU topics go beyond tech prowess and applications
#  Author: Peter Wayner
#  Description: GPUs were once only noticed by gamers and AI scientists, but they are now key components in many of the most essential parts of the economy. GPUs are the highest-profile circuits sold at the highest prices and are of flagship for the entire industry. When the…
#  URL: https://venturebeat.com/2022/03/21/gtc-2020-gpu-topics-go-beyond-tech-prowess-and-applications/
#
#
#
# Article 10
#  Title: GTC 2022: NVIDIA flexes its GPU and platform muscles
#  Author: Chris J. Preimesberger, Zeus Kerravala
#  Description: NVIDIA's CEO Jensen Huang's 1 hour, 39-minute keynote covered a lot of ground but the unifying themes to the majority of the two dozen announcements were GPU-centered, and its platform approach to everything it builds.
#  URL: https://venturebeat.com/2022/03/22/gtc-2022-nvidia-flexes-its-gpu-and-platform-muscles/
#
#
#
# Article 11
#  Title: Lenovo Unveils New Range of Portable Machines for More Casual Gamers
#  Author: Asha Barbaschow
#  Description: Lenovo has released a new range of laptops it says are perfect for “younger” or “new” gamers entering the world of gaming – they also wouldn’t be terrible portable machines for more casual play, with a max weight of 2.5 kgs.Read more...
#  URL: https://gizmodo.com/lenovo-unveils-new-range-of-portable-machines-for-more-1848613999
#
#
#
# Article 12
#  Title: Piet-GPU Progress: Clipping
#  Author: None
#  Description: Recently piet-gpu has taken a big step towards realizing its vision, moving the computation of path clipping from partially being done on the CPU to entirely being done on the GPU.
#  URL: https://raphlinus.github.io/rust/graphics/gpu/2022/02/24/piet-gpu-clipping.html
#
#
#
# Article 13
#  Title: Dell XPS 15 review: too hot to handle
#  Author: Monica Chin
#  Description: Loud, hot, but OLED it’s got.
#  URL: https://www.theverge.com/22958468/dell-xps-15-2021-oled-review
#
#
#
# Article 14
#  Title: M1 Ultra CPU is 60% Faster Than 28-core Mac Pro, GPU is 80% Faster Than Highest-End Radeon Pro W6900X Graphics Card
#  Author: Juli Clover
#  Description: The newly announced M1 Ultra is now Apple's fastest Apple silicon chip, unseating the M1 Max as the top-of-the-line option. With the power of the updated chip, the new Mac Studio is able to outperform not only the high-end prior-generation 27-inch iMac, but a…
#  URL: https://www.macrumors.com/2022/03/08/m1-ultra-cpu-mac-pro-comparison/
#
#
#
# Article 15
#  Title: Apple Announces 'M1 Ultra' Chip With 20-Core CPU, 64-Core GPU, and Support for 128GB of Memory
#  Author: Sami Fathi
#  Description: Apple today announced the M1 Ultra chip, the third iteration to the ‌M1‌ family, and it represents the next "breakthrough" for Apple Silicon.
#
#
#
#
#
# ‌M1‌ Ultra consists of two M1 Max chips connected with die-to-die technology called "UltraFusion." The new highe…
#  URL: https://www.macrumors.com/2022/03/08/apple-announces-m1-ultra-chip/
#
#
#
# Article 16
#  Title: The Most Intriguing Launches at MWC 2022 Weren’t Phones
#  Author: Adam Speight
#  Description: Laptops and 2-in-1 devices were out in force at the Mobile World Congress convention in Barcelona. And they stole the show.
#  URL: https://www.wired.com/story/mwc-2022-laptops-tablets-other-surprises/
#
#
#
# Article 17
#  Title: Dynabook’s new Portégé will be one of the lightest laptops you can buy
#  Author: Monica Chin
#  Description: The Dynabook Portégé X40L-K is a new 2.3-pound 14-inch laptop powered by 12th-Gen Intel chips. It launches in April and will start at $1,799.99.
#  URL: https://www.theverge.com/2022/3/3/22958980/dynabook-portege-x40l-k-laptop-prirce-release-date-specs
#
#
#
# Article 18
#  Title: More Apple M1 Ultra Benchmarks Show It Doesn't Beat the Best GPUs from Nvidia and AMD
#  Author: EditorDavid
#  Description: Tom's Guide tested a Mac Studio workstation equipped with an M1 Ultra with the Geekbench 5.4 CPU benchmarks "to get a sense of how effectively it handles single-core and multi-core workflows."
#
# "Since our M1 Ultra is the best you can buy (at a rough price of…
#  URL: https://hardware.slashdot.org/story/22/03/19/2031214/more-apple-m1-ultra-benchmarks-show-it-doesnt-beat-the-best-gpus-from-nvidia-and-amd
#
#
#
# Article 19
#  Title: Deals: Apple's 24-Inch iMac Hits Record Low Prices at Up to $150 Off
#  Author: Mitchel Broussard
#  Description: B&H Photo is offering a few solid deals on Apple's 24-inch iMac, starting with the 7-core GPU/256GB model for $1,199.00, down from $1,299.00. This price is only available in the Pink color, and Silver is at a second-best price of $1,229.00 on B&H Photo and Am…
#  URL: https://www.macrumors.com/2022/03/21/deals-24-inch-imac-record-low/
#
#
#
# Language used for search: es
# Article 0
#  Title: Los primeros benchmarks del M1 Ultra salen a la luz: ¿cumple con lo que promete?
#  Author: Rubén Chicharro
#  Description: Una de las sorpresas del pasado evento de Apple fue el anuncio del chip M1 Ultra. Se trata del nuevo procesador para el Mac Studio —y probablemente para futuros ordenadores de la compañía— que con su CPU de hasta 20 núcleos, una GPU de 64 núcleos y la posibil…
#  URL: https://hipertextual.com/2022/03/los-primeros-benchmarks-del-m1-ultra-salen-a-la-luz-cumple-con-lo-que-promete
#
#
#
# Article 1
#  Title: ¿Disfrutar juegos de Steam en un Tesla? Elon Musk quiere hacerlo realidad
#  Author: Tomás Rivero
#  Description: Los vehículos eléctricos siguen dando saltos tecnológicos. Ahora, los coches Tesla podrían volver a aprovechar su hardware para una actividad de entretenimiento. Según las palabras de su fundador, Elon Musk, muy pronto podrías disfrutar juegos de Steam desde …
#  URL: https://hipertextual.com/2022/02/juegos-steam-tesla-elon-musk
#
#
#
# Article 2
#  Title: Apple lanza el procesador M1 Ultra: el chip más potente de la familia se desmarca con 20 núcleos de CPU y 64 de GPU
#  Author: Juan Carlos López
#  Description: Apple acaba de estrenar un nuevo microprocesador de la familia M1. Y, según los de Cupertino, es el más potente de todos. Sus cifras prometen. Mucho. Y es que incorpora 20 núcleos de CPU, 64 núcleos para los gráficos, y tiene una potencia de 21 TFLOPS. No obs…
#  URL: https://www.xataka.com/componentes/apple-lanza-procesador-m1-ultra-chip-potente-familia-se-desmarca-20-nucleos-cpu-64-gpu
#
#
#
# Article 3
#  Title: Era sólo malware, pero a los usuarios de Nvidia RTX les prometió desbloquear sus capacidades de minería de Ethereum
#  Author: Bárbara Bécares
#  Description: Una herramienta publicada en GitHub que se anunciaba como que podía desbloquear todas las capacidades de minería de Ethereum de las recientes tarjetas gráficas Nvidia RTX, pero en realidad contiene malware. De hecho, la publicación de GitHub ya no está dispon…
#  URL: https://www.genbeta.com/actualidad/era-solo-malware-a-usuarios-nvidia-rtx-les-prometio-desbloquear-sus-capacidades-mineria-ethereum
#
#
#
# Article 4
#  Title: Xiaomi RedmiBook Pro 15 (2022): pantalla 3.2K y los últimos procesadores de Intel en un ultrabook a precio de derribo
#  Author: Enrique Pérez
#  Description: Junto al potente Redmi K50 Pro y la gran Redmi MAX 100, tenemos otro dispositivo de Xiaomi de primer nivel. En este caso un nuevo portátil, el Xiaomi RedmiBook Pro 15 (2022). Se trata de la nueva generación del ultrabook de la marca Redmi más avanzado, que es…
#  URL: https://www.xataka.com/ordenadores/xiaomi-redmibook-pro-15-2022-caracteristicas-precio-ficha-tecnica
#
#
#
# Article 5
#  Title: Apple iPhone SE (2022): el rey de los móviles pequeños vuelve con más potencia que nunca
#  Author: Enrique Pérez
#  Description: Ya tenemos nuevo "iPhone barato". El iPhone SE (2022) es el sucesor del iPhone SE 2020, la alternativa oficial más asequible para acceder al ecosistema de Apple. Durante su primera keynote de 2022, la compañía ha dado a conocer su nuevo móvil más compacto y e…
#  URL: https://www.xataka.com/moviles/apple-iphone-se-2022-caracteristicas-precio-ficha-tecnica
#
#
#
# Article 6
#  Title: El Mac Studio tiene ranuras para añadir más memoria SSD, pero no te emociones
#  Author: Rubén Chicharro
#  Description: El Mac Studio, el nuevo equipo de Apple con chip M1 Max y M1 Ultra, cuenta con un slot adicional para añadir más memoria SSD, según ha mostrado el youtuber Max Yuryev, del canal Max Tech, tras realizar el desmontaje del ordenador. Yuryev, además, asegura que …
#  URL: https://hipertextual.com/2022/03/mac-studio-ranuras-ssd
#
#
#
# Article 7
#  Title: Qué ha pasado con Nvidia: hackers latinoamericanos ponen en jaque al gigante de las gráficas
#  Author: Rubén Chicharro
#  Description: Se ha vuelto común ver cómo grandes compañías o instituciones, sufren ataques de ransomware realizados por hackers. Estos, a menudo, "secuestran" información importante, como datos privados de los clientes, para posteriormente exigir una gran cantidad de dine…
#  URL: https://hipertextual.com/2022/03/que-ha-pasado-con-nvidia-hackers-latinoamericanos-ponen-en-jaque-al-gigante-de-las-graficas
#
#
#
# Article 8
#  Title: Del M1 al M1 Ultra: los cuatro chips de Apple que han cambiado al Mac para siempre
#  Author: Eduardo Archanco
#  Description: Con la presentación de las novedades de Peek performance ayer vimos un nuevo capítulo del poderío del Apple Silicon. Uno llamado M1 Ultra que supone también el punto final de esta generación. Es el momento de repasar toda la trayectoria del chip M1 hasta hoy.…
#  URL: https://www.applesfera.com/sobremesa/m1-al-m1-ultra-cuatro-chips-apple-que-han-cambiado-al-mac-para-siempre
#
#
#
# Article 9
#  Title: Microsoft también habría sido hackeada por LAPSUS$, el grupo que atacó a NVIDIA, Samsung y Mercado Libre
#  Author: Gabriel Erard
#  Description: LAPSUS$ ataca de nuevo. El grupo de piratas informáticos habría vuelto al ruedo con un nuevo hackeo de alto nivel, pues habría ganado acceso a los servidores de Microsoft. Según una captura de pantalla publicada en su canal de Telegram, los hackers podrían te…
#  URL: https://hipertextual.com/2022/03/microsoft-posible-hackeo-lapsus
#
#
#
# Article 10
#  Title: Huawei lanza en Europa los MateBook E, MateBook X Pro y MateStation X
#  Author: Rubén Chicharro
#  Description: El Mobile World Congress vuelve a la normalidad tras su cancelación en 2020 y su versión descafeinada en 2021, y fabricantes como Huawei han aprovechado el marco de este congreso para anunciar sus novedades para el mercado europeo. La compañía china, en concr…
#  URL: https://hipertextual.com/2022/02/huawei-lanza-en-europa-los-matebook-e-matebook-x-pro-y-matestation-x
#
#
#
# Article 11
#  Title: Apple lanzaría el Mac Studio, un nuevo ordenador inspirado en el Mac mini, pero con un rendimiento superior
#  Author: Ebenizer Pinedo
#  Description: Apple se encuentra trabajando en una nueva línea de ordenadores de sobremesa, según 9to5Mac. De manera interna, los de Cupertino la conocen con el nombre en código "J375". No obstante, comercialmente sería conocido como Mac Studio. En cuanto a sus característ…
#  URL: https://hipertextual.com/2022/03/apple-mac-studio-nuevo-ordenador-filtrado
#
#
#
# Article 12
#  Title: El Nubia RedMagic 7 llega a España: precio y disponibilidad oficiales del nuevo monstruo para gaming
#  Author: Jose García
#  Description: Hace algunos días Nubia anunció su nueva hornada de móviles gaming, los RedMagic 7 y 7 Pro. Son dos terminales con mucho de todo, con potencia a patadas (hasta 18 GB de memoria RAM, sin ir más lejos) y con un buen lote de funciones pensadas para los más jugon…
#  URL: https://www.xataka.com/moviles/nubia-redmagic-7-llega-a-espana-precio-disponibilidad-oficiales-nuevo-monstruo-para-gaming
#
#
#
# Article 13
#  Title: Realme Narzo 50: el nuevo gama media de Realme no escatima en Hz y mAh
#  Author: Jose García
#  Description: Y llegó el tercer Narzo 50. Después de presentar los Realme Narzo 50A y Realme Narzo 50i, Realme acaba de anunciar en India el lanzamiento del Realme Narzo 50 (a secas). Se trata de un dispositivo de gama media que incorpora un panel de 120 Hz y el procesador…
#  URL: https://www.xataka.com/moviles/realme-narzo-50-caracteristicas-precio-ficha-tecnica
#
#
#
# Article 14
#  Title: Cazando Gangas en informática y gaming: 13 ordenadores a precio de derribo, la Xbox Series S más barata y más ofertas
#  Author: Eva Rodríguez de Luis
#  Description: Estos días es el 17 Aniversario de PcComponentes y sus ofertas protagonizan nuestra sección de informática, aunque no son las únicas. Si te toca cambiar de ordenador, buscas un monitor bien de precios o periféricos de oferta, estás en el lugar adecuado. Esto …
#  URL: https://www.xataka.com/cazando-gangas/cazando-gangas-informatica-gaming-13-ordenadores-a-precio-derribo-xbox-series-s-barata-ofertas
#
#
#
# Article 15
#  Title: Apple no lo ha puesto fácil, pero ya es posible instalar Linux en los Mac con los chips M1
#  Author: Javier Pastor
#  Description: En noviembre de 2020 Apple iniciaba su particular revolución con los chips M1, pero lo hacía con una desventaja clara para los usuarios: no se podría ya instalar Windows o Linux en estos equipos de forma nativa.
# <!-- BREAK 1 -->
# Eso obligaba a usar soluciones…
#  URL: https://www.xataka.com/aplicaciones/apple-no-ha-puesto-facil-posible-instalar-linux-mac-chips-m1
#
#
#
# Article 16
#  Title: El ordenador portátil más vendido de Amazon es este Asus TUF Gaming F15 con RTX 3050 y 16GB RAM a precio mínimo histórico de 749 euros
#  Author: Eva Rodríguez de Luis
#  Description: Que un ordenador portátil de 749 euros reine entre los más vendidos de Amazon (según Amazon) no es casual, pero teniendo en cuenta el hardware que monta y que esté más barato que nunca son dos motivos de peso. Si buscas un equipo todoterreno para meterle caña…
#  URL: https://www.xataka.com/seleccion/ordenador-portatil-vendido-amazon-este-asus-tuf-gaming-f15-rtx-3050-16gb-ram-a-precio-minimo-historico-749-euros
#
#
#
# Article 17
#  Title: Qué es DirectStorage, la tecnología de Xbox que acaba de llegar a Windows 10 y 11 para cargar tus juegos más rápido que nunca
#  Author: Gabriela González
#  Description: Cuando Microsoft anunció su consola insignia de nueva generación, la Xbox Series X, lo hizo mostrando una serie de nuevas tecnologías llamadas Xbox Velocity Architecture diseñadas para aprovechar al máximo el potencial del nuevo hardware de punta que nos traí…
#  URL: https://www.genbeta.com/windows/que-directstorage-tecnologia-xbox-que-acaba-llegar-a-windows-10-11-para-cargar-tus-juegos-rapido-que-nunca
#
#
#
# Article 18
#  Title: Honor Magic4 Pro, primeras impresiones: Honor pide sitio en la liga de los móviles de más de 1.000 euros
#  Author: Enrique Pérez
#  Description: El Honor Magic4 Pro no deja indiferente. Con ese módulo circular enorme para su triple cámara, con su super carga inalámbrica de 100W o con su pantalla curvada de 6,8 pulgadas con 120 Hz y AMOLED LTPO. Especificaciones de primer nivel para un buque insignia c…
#  URL: https://www.xataka.com/moviles/honor-magic4-pro-opiniones-toma-contacto-video-fotos
#
#
#
# Article 19
#  Title: El iMac de 24" con GPU de ocho núcleos y Magic Keyboard con Touch ID alcanza su precio mínimo histórico: 1.449 euros
#  Author: Jesús Quesada
#  Description: Uno de los ordenadores con chip M1 más esperados por los usuarios era el iMac, y hace unos meses que lo tenemos con nosotros y con un ligero lavado de cara. Disponible en distintas configuraciones, la de CPU/GPU de ocho núcleos y teclado Magic Keyboard con To…
#  URL: https://www.applesfera.com/seleccion/imac-24-gpu-ocho-nucleos-magic-keyboard-touch-id-alcanza-su-precio-minimo-historico-1-449-euros
#
#
#
# Language used for search: fr
# Article 0
#  Title: Nvidia : le géant des GPU “entièrement compromis” par une cyberattaque
#  Author: Antoine Gautherie
#  Description: Le géant vert américain a été victime d'une intrusion qui a permis à des pirates de récupérer, entre autres, des données sensibles sur des projets stratégiques de la marque.
# Nvidia : le géant des GPU “entièrement compromis” par une cyberattaque
#  URL: https://www.journaldugeek.com/2022/03/01/nvidia-le-geant-des-gpu-entierement-compromis-par-une-cyberattaque/
#
#
#
# Article 1
#  Title: PyTorch on Apple M1 Faster Than TensorFlow-Metal
#  Author: Nod Team
#  Description: Comments
#  URL: https://nod.ai/pytorch-m1-max-gpu/
#
#
#
# Article 2
#  Title: Nvidia RTX 3090 Ti : enfin une date de sortie pour la future reine des GPU
#  Author: Antoine Gautherie
#  Description: Après une longue attente, plusieurs indices semblent indiquer que la future reine du catalogue RTX arrivera sur le marché à la fin du mois.
# Nvidia RTX 3090 Ti : enfin une date de sortie pour la future reine des GPU
#  URL: https://www.journaldugeek.com/2022/03/09/nvidia-rtx-3090-ti-enfin-une-date-de-sortie-pour-la-future-reine-des-gpu/
#
#
#
# Article 3
#  Title: M1 Ultra : la puce Apple est-elle plus performante qu’une RTX 3090 ?
#  Author: Thomas Estimbre
#  Description: Avec sa puce M1 Ultra, Apple ambitionne de battre la RTX 3090 de Nvidia grâce à un procédé novateur. Il convient cependant de rester prudent. Explications.
# M1 Ultra : la puce Apple est-elle plus performante qu’une RTX 3090 ?
#  URL: https://www.journaldugeek.com/2022/03/10/m1-ultra-la-puce-apple-est-elle-plus-performante-quune-rtx-3090/
#
#
#
# Article 4
#  Title: Actualité : Cyberattaque de Nvidia : des caractéristiques techniques des GPU Ada et des GeForce RTX 40 ont fuité
#  Author: Régis Jehl
#  Description: Victime d’une cyberattaque il y a quelques jours, Nvidia subit désormais la publication de données confidentielles. Ces fuites concernent notamment les GeForce RTX 40 et leurs GPU Ada dont certains détails techniques ont été dévoilés.
#  URL: https://www.lesnumeriques.com/carte-graphique/cyberattaque-de-nvidia-des-caracteristiques-techniques-des-gpu-ada-et-des-geforce-rtx-40-ont-fuite-n177691.html
#
#
#
# Article 5
#  Title: Nvidia Hopper H100 donne le tournis : le plus gros GPU au monde, 3x la puissance d’Ampere
#  Author: Cassim Ketfi
#  Description: Comme prévu, Nvidia a profité de la GTC, mardi, pour lever le voile sur une nouvelle architecture : Nvidia Hopper, en hommage à Grace Hopper. La puce Nvidia H100 est la première à utiliser cette architecture. Deux ans après la présentation de l’architecture A…
#  URL: https://www.frandroid.com/marques/nvidia/1272805_nvidia-hopper-h100-annonce-gtc
#
#
#
# Article 6
#  Title: Ce PC portable gaming Asus Dash F15 avec une RTX 3060 est à moins de 1000€ !
#  Author: Gregori Pujol
#  Description: Vous souhaitez vous équiper d'un PC portable gamer gamer et disposez d'un budget sous la barre des 1 000 euros ? Aujourd'hui, Cdiscount propose justement une promotion sur le modèle Asus TUF Dash F15. Vous pouvez l'acheter moins cher, à 949 € au lieu de 1 199…
#  URL: https://www.journaldugeek.com/bon-plan/ce-pc-portable-gaming-asus-dash-f15-avec-une-rtx-3060-est-a-moins-de-1000e/
#
#
#
# Article 7
#  Title: Apple M1 Ultra : une puce ultra puissante pour les Mac
#  Author: Thomas Estimbre
#  Description: Intégrée au tout nouveau Mac Studio, la puce M1 Ultra marque un nouveau tournant dans la transition vers les puces Apple. Focus sur ce nouveau SoC qui va équiper les ordinateurs les plus puissants de la marque.
# Apple M1 Ultra : une puce ultra puissante pour l…
#  URL: https://www.journaldugeek.com/2022/03/08/apple-m1-ultra-une-puce-ultra-puissante-pour-les-mac/
#
#
#
# Article 8
#  Title: Ce mini PC gaming de Chuwi est à un prix indécent !
#  Author: Gabriel Foffano
#  Description: Vous avez envie de jouer aux jeux vidéo à partir d'un ordinateur ? Ce bon plan concernant ce miniordinateur de bureau gaming de Chuwi tombe à point nommé.
# Ce mini PC gaming de Chuwi est à un prix indécent !
#  URL: https://www.journaldugeek.com/bon-plan/ce-mini-pc-gaming-de-chuwi-est-a-un-prix-indecent/
#
#
#
# Article 9
#  Title: Intel va bien lancer ses premiers GPU Arc à la fin du mois… mais pas ceux qu’on espérait
#  Author: Juliette Rivière
#  Description: Avec sa gamme ARC, Intel a prévu de débarquer en grande pompe sur le marché des cartes graphiques dédiées. Et c'est par les GPU pour PC portables que le constructeur américain commencerait sa croisade, dès la fin du mois de mars.Les choses avancent du côté de…
#  URL: https://www.frandroid.com/marques/intel-materiels-accessoires/1261479_cest-officiel-intel-va-lancer-ses-premiers-gpu-arc-a-la-fin-du-mois
#
#
#
# Article 10
#  Title: Un nouvel espoir pointe une possible baisse du prix des cartes graphiques
#  Author: Nathan Le Gohlisse
#  Description: Nvidia a informé ses partenaires d'une baisse du coût de ses GPU. Il s'agit d'une bonne nouvelle, car elle devrait se répercuter auprès des joueurs... mais attention : rien ne dit que l'approvisionnement sera amélioré dans le même temps.8 à 12 % de baisse des…
#  URL: https://www.frandroid.com/produits-android/hardware/cartes-graphiques/1267537_un-nouvel-espoir-pointe-une-possible-baisse-du-prix-des-cartes-graphiques
#
#
#
# Article 11
#  Title: Actualité : Labo – On a testé la carte graphique Radeon RX 6800S du ROG Zephyrus G14
#  Author: Raphaël Bentéo
#  Description: Si les cartes graphiques Radeon d'AMD sont une minorité sur le marché des PC portables, quelques modèles en sont tout de même dotés. C'est le cas du nouveau ROG Zephyrus G14 d'Asus qui embarque une RX 6800S que nous avons criblée de tests.
#  URL: https://www.lesnumeriques.com/carte-graphique/labo-on-a-teste-la-carte-graphique-radeon-rx-6800s-du-rog-zephyrus-g14-n178827.html
#
#
#
# Article 12
#  Title: Actualité : Labo – Série Samsung Galaxy S22 : les performances de l'Exynos 2200 à la loupe
#  Author: Laure Renouard
#  Description: La série Galaxy S22 de Samsung s'appuie sur une nouvelle puce mobile : l'Exynos 2200, successeur d’un Exynos 2100 performant et misant sur une nouvelle architecture. Une puce qui mérite plus ample examen, d'autant qu'elle soulève des interrogations techniques.
#  URL: https://www.lesnumeriques.com/telephone-portable/labo-serie-samsung-galaxy-s22-les-performances-de-l-exynos-2200-a-la-loupe-n177171.html
#
#
#
# Article 13
#  Title: Apple M1 Ultra : pourquoi ce processeur est si impressionnant
#  Author: Ulrich Rozier
#  Description: La puce M1 Ultra d'Apple est un monstre. Cette puce contourne les limitations physiques qui se produisent normalement lorsque deux puces sont couplées et cela promet des performances incroyables avec une faible consommation d'énergie. Regardons de plus près c…
#  URL: https://www.frandroid.com/marques/apple/1258011_apple-m1-ultra-pourquoi-ce-processeur-est-si-impressionnant
#
#
#
# Article 14
#  Title: Test Asus ROG Strix Scar 17 : le PC portable gaming de tous les superlatifs
#  Author: Guillaume Henri
#  Description: L'Asus ROG Strix Scar 17 est le fer de lance de la gamme Republic of Gamers. Cette version est équipée d'un processeur Intel Core i9-12900H avec architecture Alder Lake, tandis que le GPU est confié à la GeForce RTX 3070 Ti de Nvidia.
#  URL: https://www.lesnumeriques.com/ordinateur-portable/asus-rog-strix-scar-17-rtx-3070-ti-120-hz-p67307/test.html
#
#
#
# Article 15
#  Title: Snapdragon Wear 5100 : grâce à de nouvelles fuites, on en sait plus sur le SoC qui équipera les prochaines montres connectées
#  Author: Rémi Bouvet
#  Description: Des Snapdragon Wear 5100 et 5100+ gravés en 4 nm par Samsung, qui auront également droit à un nouveau GPU.
#  URL: https://www.clubic.com/pro/entreprises/qualcomm/actualite-410463-snapdragon-wear-5100-grace-a-de-nouvelles-fuites-on-en-sait-plus-sur-le-soc-qui-equipera-les-prochaines-montres-connectees.html
#
#
#
# Article 16
#  Title: NVIDIA : un premier cliché du Hopper H100, l'énorme GPU pour serveurs
#  Author: Nerces
#  Description: La nouvelle génération de GPU
#  NVIDIA pour centres de données se dévoile doucement.
#  URL: https://www.clubic.com/pro/entreprises/nvidia/actualite-414567-nvidia-un-premier-cliche-du-hopper-h100-l-enorme-gpu-pour-serveurs.html
#
#
#
# Article 17
#  Title: Actualité : Fuite de données Nvidia : la Nintendo Switch Pro ou “4K” était bien prévue
#  Author: Mathieu Chartier
#  Description: Il n'y a pas de fumée sans feu. Il semblerait que les innombrables rumeurs concernant une Nintendo Switch “4K” plus puissante étaient fondées. Pour preuve, Nvidia aurait développé une nouvelle puce Tegra custom pour la console.
#  URL: https://www.lesnumeriques.com/console-de-jeu/fuite-de-donnees-nvidia-la-nintendo-switch-pro-ou-4k-etait-bien-prevue-n177709.html
#
#
#
# Article 18
#  Title: Comment suspendre un jeu ou un gros traitement (Linux / Windows) ?
#  Author: Korben
#  Description: Comment suspendre un jeu ou un gros traitement ?
#  URL: https://korben.info/comment-suspendre-un-jeu-ou-un-gros-traitement-linux-windows.html
#
#
#
# Article 19
#  Title: Le premier PC portable sous Intel Arc se montre par erreur, vers une annonce fin de mois ?
#  Author: Rémi Bouvet
#  Description: Un détaillant a référencé l’ordinateur Samsung Galaxy Book 2 Pro armé d’un GPU dédié Intel Arc avec un peu d’avance…
#  URL: https://www.clubic.com/pro/entreprises/intel/actualite-414165-le-premier-pc-portable-sous-intel-arc-se-montre-par-erreur-vers-une-annonce-fin-de-mois.html
#
#
#
# Language used for search: he
# Article 0
#  Title: אפל הכריזה על המעבד המתקדם ביותר שלה: M1 Ultra
#  Author: אושרי אלקסלסי
#  Description: פחות משנה וחצי אחרי השקת המעבד הראשון שפיתחה אחרי הפרידה מאינטל, אפל הציגה מעבד חדש - הבנוי משניים מהשבבים החזקים ביותר שלה שמחוברים יחד. מה הוא מציע?
# The post אפל הכריזה על המעבד המתקדם ביותר שלה: M1 Ultra first appeared on גיקטיים.
#  URL: https://www.geektime.co.il/apple-announces-new-chip-m1-ultra/
#
#
#
# Article 1
#  Title: טייגר גלובל ואינסייט משקיעות 75 מיליון דולר בסטארטאפ שמאפשר לאמן מודלי ML בפרודקשן
#  Author: אושרי אלקסלסי
#  Description: 2 מהקרנות הגדולות שפועלות בישראל משקיעות בפיתוח של Run:AI, שמאפשר שיפור משמעותי בזמן האימון של מודלי בינה מלאכותית
# The post טייגר גלובל ואינסייט משקיעות 75 מיליון דולר בסטארטאפ שמאפשר לאמן מודלי ML בפרודקשן first appeared on גיקטיים.
#  URL: https://www.geektime.co.il/the-avengers-of-the-vc-world-lead-a-75m-funding-round-for-runai/
#
#
#
# Article 2
#  Title: אנבידיה מכריזה על מחשב על-חדש, ומעבד שמזכיר את המעבד המתקדם ביותר של אפל
#  Author: אושרי אלקסלסי
#  Description: ענקית השבבים הציגה את הדור הבא של ה-CPU שלה, שמגיע עם חיבור חדש שמזכיר מאוד את השבב שאפל הציגה בתחילת החודש. בנוסף הציגה מחשב על שאמור להיות המהיר ביותר ודרך מעניינת לנסות ולהתמודד עם שינויי האקלים
# The post אנבידיה מכריזה על מחשב על-חדש, ומעבד שמזכיר את המעבד…
#  URL: https://www.geektime.co.il/nvidia-gtc-2022-announcements/
#
#
#
# Article 3
#  Title: אפל הציגה את מחשב הדסקטופ הכי חזק שלה: Mac Studio
#  Author: עידן בן טובים
#  Description: אפל הכריזה בהפתעה על מחשב דסקטופ חדש לחלוטין ועל תצוגה מתקדמת שמביאה את הפיצר המבוקש מה-iPad שישדרג לכם את שיחות הוידאו
# The post אפל הציגה את מחשב הדסקטופ הכי חזק שלה: Mac Studio first appeared on גיקטיים.
#  URL: https://www.geektime.co.il/apple-announces-mac-studio-and-studio-display/
#
#
#
# Language used for search: it
# Article 0
#  Title: Il nuovo Dimensity 8100 di MediaTek promette prestazioni simili allo Snapdragon 888
#  Author: Antonio Lepore
#  Description: Notizie in arrivo sul nuovo chip di Mediatek, il Dimensity 8100. In un nuovo post su Weibo, Digital Chat Station...
# L'articolo Il nuovo Dimensity 8100 di MediaTek promette prestazioni simili allo Snapdragon 888 sembra essere il primo su Mobileworld.
#  URL: https://www.mobileworld.it/hardware/il-nuovo-dimensity-8100-di-mediatek-promette-prestazioni-simili-allo-snapdragon-888.html
#
#
#
# Article 1
#  Title: NVIDIA GeForce RTX 4000: TDP sino a 850W per i modelli più spinti | Rumor
#  Author: HDblog.it
#  Description: Secondo le ultime indiscrezioni i consumi delle GPU Ada Lovelace saranno a dir poco estremi.
#  URL: https://www.hdblog.it/hardware/articoli/n551930/geforce-rtx-4000-tdp-850w-consumi-prestazioni/
#
#
#
# Article 2
#  Title: Nvidia hack, LAPSU$ rilascia i sorgenti del DLSS e chiede driver open-source
#  Author: HDblog.it
#  Description: La società ha tempo fino a venerdì per decidere. Gli hacker minacciano di rilasciare tutti i documenti su GPU, chipset e schede video.
#  URL: https://www.hdblog.it/hardware/articoli/n552268/nvidia-hacker-dlss-sorgente-driver-open-source/
#
#
#
# Article 3
#  Title: Blender 3.1 porta il rendering Metal GPU sui Mac M1
#  Author: Yuri Di Prodo
#  Description: Con la versione 3.1 il software di modellazione 3D Blender diventa velocissimo grazie alla accelerazione grafica via GPU su Mac M1
# - su macitynet.it Blender 3.1 porta il rendering Metal GPU sui Mac M1
#  URL: https://www.macitynet.it/blender-3-1-porta-il-rendering-metal-gpu-sui-mac-m1/
#
#
#
# Article 4
#  Title: Intel Arc Alchemist: tutto quello che sappiamo sulle GPU gaming Intel
#  Author: HDblog.it
#  Description: Un piccolo recap sulle prime schede grafiche prodotte da Intel.
#  URL: https://www.hdblog.it/hardware/speciali/n551283/intel-arc-alchemist-gpu-speciiche-quando-escono/
#
#
#
# Article 5
#  Title: Arc Alchemist, rumor sempre più compatti: "Ritardi, lancio tra maggio e giugno"
#  Author: HDblog.it
#  Description: Partner di Intel ancora in attesa dei campioni di valutazione.
#  URL: https://www.hdblog.it/hardware/articoli/n552603/intel-arc-alchemist-lancio-maggio-giugno-rumor/
#
#
#
# Article 6
#  Title: Intel Arc Alchemist, irrompe a sorpresa la prima "recensione" della A380 desktop
#  Author: HDblog.it
#  Description: Sette benchmark a confronto con quattro rivali, e le considerazioni finali di SiSoftware.
#  URL: https://www.hdblog.it/hardware/articoli/n551781/intel-arc-alchemist-a380-gpu-prima-recensione/
#
#
#
# Article 7
#  Title: GPU di M1 Ultra più veloce di una GeForce RTX 3090? Apple pensa di sì, i test dicono di no
#  Author: None
#  Description: Apple ha dichiarato durante la conferenza di presentazione di Mac Studio che la GPU del nuovo chip M1 Ultra è più veloce di una GeForce RTX 3090 pur consumano 200 watt in meno. I primi test svolti negli Stati Uniti dicono però che la GPU di NVIDIA è ancora da…
#  URL: https://www.hwupgrade.it/news/skvideo/gpu-di-m1-ultra-piu-veloce-di-una-geforce-rtx-3090-apple-pensa-di-si-i-test-dicono-di-no_105703.html
#
#
#
# Article 8
#  Title: MediaTek al MWC con tre SoC 5G di fascia alta: Dimensity 8100, 8000 e 1300
#  Author: HDblog.it
#  Description: Il denominatore comune sono i quattro core Cortex-A78 e i quattro Cortex-A55 della CPU; cambiano frequenze, gerarchia e processo produttivo.
#  URL: https://www.hdblog.it/hardware/articoli/n552121/mediatek-dimensity-8100-8000-1300-ufficiali/
#
#
#
# Article 9
#  Title: GeForce RTX 4000: fino a 144 SM per le GPU Ada Lovelace di NVIDIA?
#  Author: None
#  Description: Secondo i file rubati a NVIDIA e finiti in rete, la GPU di nuova generazione AD102 potrebbe integrare il 71% in più di CUDA core rispetto all'attuale chip GA102 usato in diverse schede video top di gamma della famiglia GeForce RTX 3000.
#  URL: https://www.hwupgrade.it/news/skvideo/geforce-rtx-4000-fino-a-144-sm-per-le-gpu-ada-lovelace-di-nvidia_105261.html
#
#
#
# Article 10
#  Title: Mercato GPU, consegne in calo del 15% su base annua nel quarto trimestre 2021
#  Author: None
#  Description: Secondo i dati degli analisti di John Peddie Research, il mercato delle GPU per PC ha visto crescere le consegne dello 0,8% rispetto al trimestre precedente, mentre il dato è in calo del 15% rispetto allo stesso periodo del 2020.
#  URL: https://www.hwupgrade.it/news/skvideo/mercato-gpu-consegne-in-calo-del-15-su-base-annua-nel-quarto-trimestre-2021_105095.html
#
#
#
# Article 11
#  Title: Intel Arc Alchemist, niente supporto all'accelerazione dei calcoli FP64 (e non c'è da stupirsi)
#  Author: None
#  Description: Nessuna unità hardware FP64 per l'accelerazione dei calcoli in virgola mobile a doppia precisione per le GPU Arc "Alchemist" di Intel in arrivo sul mercato. Una scelta sensata, visto il settore a cui si rivolgono e in linea con quella dei concorrenti.
#  URL: https://www.hwupgrade.it/news/skvideo/intel-arc-alchemist-niente-supporto-all-accelerazione-dei-calcoli-fp64-e-non-c-e-da-stupirsi_105234.html
#
#
#
# Article 12
#  Title: Nintendo Switch 2: i leak Nvidia anticipano il chip della prossima console
#  Author: HDblog.it
#  Description: Si torna a parlare di Switch 2, grazie ad una nuova serie di informazioni trafugate direttamente da Nvidia
#  URL: https://www.hdblog.it/nintendo/articoli/n552194/nintendo-switch-2-rumor-dlss-nvidia-ampere/
#
#
#
# Article 13
#  Title: Gigabyte UD1000GM PCIe 5.0, un alimentatore pronto per le GPU di prossima generazione
#  Author: None
#  Description: Gigabyte ha presentato l'alimentatore UD1000GM PCIe 5.0 pronto per le schede video di prossima generazione. A bordo non solo un connettore a 16 pin con relativo cavo, ma anche quattro connettori a 8 pin.
#  URL: https://www.hwupgrade.it/news/periferiche/gigabyte-ud1000gm-pcie-50-un-alimentatore-pronto-per-le-gpu-di-prossima-generazione_105024.html
#
#
#
# Article 14
#  Title: Mac Studio e Studio Display al massimo? Ecco il prezzo (ma mettetevi a sedere)
#  Author: HDblog.it
#  Description: Il nostro carrello arriverà a...
#  URL: https://www.hdblog.it/hardware/articoli/n552550/mac-studio-display-apple-configurazione-top-prezzo/
#
#
#
# Article 15
#  Title: NVIDIA GeForce RTX 4000, cache in grande aumento e informazioni sul bus di memoria
#  Author: None
#  Description: Dopo le indiscrezioni sul numero di SM e CUDA core, spuntano presunti nuovi dettagli sulle configurazioni delle GPU Ada Lovelace delle future GeForce RTX 4000: si parla di cache L2 in netto aumento, fino a 96 MB per AD102, e bus fino a 384 bit.
#  URL: https://www.hwupgrade.it/news/skvideo/nvidia-geforce-rtx-4000-cache-in-grande-aumento-e-informazioni-sul-bus-di-memoria_105297.html
#
#
#
# Article 16
#  Title: Intel, le GPU Arc per notebook svelate il 30 marzo: si parte con Arc A370M
#  Author: None
#  Description: Intel ha annunciato per il 30 marzo un evento in cui svelerà le sue prime GPU dedicate per portatili della serie Arc. L'azienda afferma che il modello A370M offrirà prestazioni due volte maggiori rispetto alla grafica integrata nelle ultime CPU.
#  URL: https://www.hwupgrade.it/news/skvideo/intel-le-gpu-arc-per-notebook-svelate-il-30-marzo-si-parte-con-arc-a370m_105627.html
#
#
#
# Article 17
# ...
#  Title: Утечка с серверов NVIDIA раскрала объём куша и количество ядер CUDA видеокарт GeForce RTX 40-й серии
#  Author: None
#  Description: Вслед за новостями о взломе и похищении данных с серверов NVIDIA в Сети стала появляться свежая информация о грядущих настольных графических ускорителях GeForce, которые придут на смену актуальному поколению Ampere. В частности, утечки сообщают названия будущ…
#  URL: https://3dnews.ru/1061221/utechki-s-serverov-nvidia-nachali-raskrivat-podrobnosti-o-budushchih-videokartah-geforce-rtx-40y-serii
#
#
#
# Article 2
#  Title: Zotac выпустила настольные GeForce RTX 3060 Ti на графических чипах от мобильных GeForce RTX 3080 Ti
#  Author: None
#  Description: В минувшем январе компания NVIDIA представила мобильную версию видеокарты GeForce RTX 3080 Ti. В её основе лежит чип GA103. Тогда же появились слухи, что компания планирует использовать такой же GPU в составе настольных моделей видеокарт. Сегодня компания Zot…
#  URL: https://3dnews.ru/1060839/zotac-vipustila-nastolnie-geforce-rtx-3080-ti-na-baze-urezannogo-mobilnogo-protsessora-nvidia-ga103
#
#
#
# Article 3
#  Title: «Сингулярность» планетарного масштаба: ИИ-инфраструктура Microsoft включает более 100 тыс. GPU, FPGA и ASIC
#  Author: None
#  Description: Microsoft неожиданно раскрыла подробности использования своей распределённой службы планирования «планетарного масштаба» Singularity, предназначенной для управления ИИ-нагрузками. В докладе компании целью Singularity названа помощь софтверному гиганту в контр…
#  URL: https://servernews.ru/1060812
#
#
#
# Article 4
#  Title: Аналитики разошлись во мнении, что станет основой следующего MacBook Air — новый M2 или очередная версия M1
#  Author: None
#  Description: Известный многочисленными подтвердившимися прогнозами аналитик компании TF International Securities Мин-Чи Куо (Ming-Chi Kuo) «твёрдо уверен», что в ожидающемся в 2022 году обновлённом ноутбуке Apple MacBook Air будет использован старый чип M1, тогда как преж…
#  URL: https://3dnews.ru/1061595/ekspert-minchi-kuo-obnovlyonniy-macbook-air-poluchit-chipsete-m1-vmesto-m2
#
#
#
# Article 5
#  Title: NVIDIA разрабатывает технологию, которая обеспечит видеокартам прямой доступ к SSD
#  Author: None
#  Description: Компания NVIDIA при содействии IBM и ряда сторонних специалистов разработала технологию, которая сделает видеокарты менее зависимыми от центральных процессоров — она предоставит будущим GPU прямой доступ к ресурсам твердотельных накопителей. Источник изображе…
#  URL: https://3dnews.ru/1062202/nvidia-obespechit-videokartam-pryamoy-dostup-k-ssd
#
#
#
# Article 6
#  Title: В минувшем квартале поставки GPU AMD выросли на 4,7%, GPU Nvidia — сократились на 2,2%
#  Author: accent@ixbt.com (Accent)
#  Description: Специалисты аналитической компании Jon Peddie Research (JPR) подготовили отчет, относящийся к мировому рынку графических процессоров (GPU) для ПК. Согласно их подсчетам, поставки GPU в четвертом квартале 2021 года составили 101 млн штук, уменьшившись в годово…
#  URL: https://www.ixbt.com/news/2022/02/23/gpu-amd-4-7-gpu-nvidia-2-2.html
#
#
#
# Article 7
#  Title: В Китае стали выпускать настольные GeForce RTX 3060 на базе GPU от мобильной версии — они намного лучше в майнинге
#  Author: None
#  Description: Некоторые китайские производители графических ускорителей начали выпуск настольных видеокарт GeForce RTX 3060 на базе графических процессоров от одноимённых мобильных видеокарт. Подобные «монстры Франкенштейна» предназначаются для майнинга. Источник изображен…
#  URL: https://3dnews.ru/1061538/v-kitae-vipuskayut-nastolnie-videokarti-geforce-rtx-3060-s-6-gbayt-videopamyati-na-baze-mobilnih-graficheskih-protsessorov
#
#
#
# Article 8
#  Title: В 2021 году поставки настольных видеокарт поднялись почти на треть — доля рынка AMD выросла до 23 %
#  Author: None
#  Description: Эксперты Jon Peddie Research уже приводили статистику четвёртого квартала по рынку графических решений в целом, куда попадают как встроенные, так и дискретные GPU. Теперь же были обнародованы данные по рынку настольных видеокарт в отдельности, на котором доля…
#  URL: https://3dnews.ru/1061058/proshliy-god-amd-zavershila-s-doley-rinka-nastolnih-videokart-v-23-
#
#
#
# Article 9
#  Title: NVIDIA может сохранить продажи видеокарт GeForce RTX 30-й серии после выхода ускорителей нового поколения
#  Author: None
#  Description: Компания NVIDIA рассматривает возможность продолжения выпуска видеокарт GeForce RTX 30-й серии после того, как на рынке появится следующее поколение графических ускорителей. Об этом на собрании инвесторов сообщила финансовый директор NVIDIA Колетт Кресс (Cole…
#  URL: https://3dnews.ru/1061541/nvidia-hochet-sohranit-prodagi-videokart-geforce-rtx-30y-serii-dage-posle-vihoda-novogo-pokoleniya-uskoriteley
#
#
#
# Article 10
#  Title: Apple представила систему-на-чипе M1 Ultra - Wylsa.com
#  Author: https://wylsa.com/author/kostyabaranov/
#  Description: <ol><li>Apple представила систему-на-чипе M1 Ultra  Wylsa.com
# </li><li>Apple представила 20-ядерный процессор  Lenta.ru
# </li><li>Mac Studio с чипом M1 Ultra показали официально. Это новая категория настольного компьютера Apple  iPhones.ru
# </li><li>Apple пр…
#  URL: https://wylsa.com/apple-predstavila-sistemu-na-chipe-m1-ultra/
#
#
#
# Article 11
#  Title: Мобильная видеокарта Intel Arc Alchemist DG2-256EU показала уровень производительности Radeon RX 580 в тесте Geekbench
#  Author: None
#  Description: В базе данных синтетического теста Geekbench 5 появилась информация о графической производительности неизвестного ноутбука на базе процессора Core i5-12500H, оснащённого дискретным графическим процессором Intel DG2 серии Arc Alchemist с 256 исполнительными бл…
#  URL: https://3dnews.ru/1061025/publikatsiya-1061025
#
#
#
# Article 12
#  Title: AMD и Xilinx анонсировали обновлённый ИИ-ускоритель VCK5000
#  Author: None
#  Description: Ранее ПЛИС Xilinx Versal уже обзавелись поддержкой HBM2e и на основе этой флагманской FPGA была создана платформа для инференс-систем VCK5000. Сейчас AMD анонсировала новую, существенно улучшенную версию этой платформы. Правда, речи об использовании сборок с …
#  URL: https://servernews.ru/1061554
#
#
#
# Article 13
#  Title: Alcatel представила ультрабюджетный смартфон V1 2021 с процессором MediaTek Helio A22 и 2 Гбайт оперативной памяти
#  Author: None
#  Description: В 2022 году Alcatel официально представила ультрабюджетный смартфон V1 2021, который пришёл на смену V1 2020, выпущенному два года назад. Новинка, ориентирована на непритязательных пользователей и должна привлечь их большим экранов, тройной основной камерой и…
#  URL: https://3dnews.ru/1060850/alcatel-predstavila-ultrabyudgetniy-smartfon-v1-2021-na-protsessore-mediatek-helio-a22
#
#
#
# Article 14
#  Title: AMD представит 17 марта технологию масштабирования FidelityFX Super Resolution 2.0
#  Author: None
#  Description: Компания AMD представит новую версию технологии масштабирования FSR 2.0 (FidelityFX Super Resolution) 17 марта. Информация подтверждается рекламными материалами AMD, оказавшимися в распоряжении портала VideoCardz. Источник изображений: VideoCardz
#  URL: https://3dnews.ru/1061933/amd-predstavit-17-marta-tehnologiyu-masshtabirovaniya-fsr-20
#
#
#
# Article 15
#  Title: Видеокарту Radeon RX 6400 протестировали в Geekbench — на 30 % медленнее Radeon RX 6500 XT
#  Author: None
#  Description: В базе данных синтетического теста Geekbench появились первые результаты проверки производительности графического ускорителя начального уровня AMD Radeon RX 6400. Напомним, что этот ускоритель был представлен одновременно с более производительной моделью Rade…
#  URL: https://3dnews.ru/1061095/poyavilis-pervie-otchyoti-o-proizvoditelnosti-videokarti-radeon-rx-6400-v-geekbench
#
#
#
# Article 16
#  Title: Слухи: TSMC столкнулась с трудностями в освоении 3-нм техпроцесса — это может нарушить платы AMD и NVIDIA
#  Author: None
#  Description: Проблемы с освоением 3-нм техпроцесса компанией TSMC могут вынудить её клиентов продлить контракты на поставки продукции на основе 5-нм технологического процесса, говорится в свежем материале тайваньского издания DigiTimes. Технические сложности, с которыми с…
#  URL: https://3dnews.ru/1060701/publikatsiya-1060701
#
#
#
# Article 17
#  Title: Слухи: только iPhone 14 Pro получат новый чип Apple A16 — обычные iPhone 14 обойдутся прошлогодним Apple A15
#  Author: None
#  Description: Известный аналитик рынка электроники Мин-Чи Куо (Ming-Chi Kuo) выступил с прогнозом, согласно которому Apple может в этом году отойти от традиционной схемы, подразумевающей, что во всех iPhone нового поколения используются новые процессоры. По словам аналитик…
#  URL: https://3dnews.ru/1061923/minchi-kuo-noviy-chipset-apple-a16-budet-ispolzovatsya-tolko-v-iphone-14-pro
#
#
#
# Article 18
#  Title: AMD представила видеокарту Radeon Pro W6600X для рабочих станций Apple Mac Pro
#  Author: None
#  Description: Компания AMD представила новый графический ускоритель Radeon Pro W6600X. Новинка предназначается эксклюзивно для компьютеров Apple, а именно для производительных рабочих станций Mac Pro. Источник изображений: AMD
#  URL: https://3dnews.ru/1061568/publikatsiya-1061568
#
#
#
# Article 19
#  Title: В продаже засветился ноутбук Samsung Galaxy Book2 Pro с видеокартой Intel Arc Alchemist
#  Author: None
#  Description: Крупный американский ретейлер BHPhotoVideo по ошибке раньше времени открыл на своём сайте страницу для предзаказов нового ноутбука Samsung Galaxy Book2 Pro, в составе которого присутствует дискретный графический ускоритель Intel Arc Alchemist. Вскоре страница…
#  URL: https://3dnews.ru/1062219/v-prodage-ranshe-vremeni-poyavilsya-noutbuk-samsung-galaxy-book2-pro-s-videokartoy-intel-arc-alchemist
#
#
#
# Language used for search: zh
# Article 0
#  Title: 36氪首发 ｜ 砺算科技完成数亿元天使轮融资，研发适用于端云边车场景的GPU
#  Author: 杨逍
#  Description: 近日，36氪获悉，芯片设计公司砺算科技完成数亿元的天使轮融资，投资人包括达泰资本、将门创投、万物创投、海松资本、协立创投，本轮融资将主要用于研发基于自研盘古架构的天图GPU芯片。
#  砺算科技成立于2021年8月，公司主要研发图形渲染GPU。其产品构思是，基于自研盘古架构开发自主知识产权的GPU产品——TrueGPU™图形芯片，可用于端、云、边、车等多个场景，配合客户进行定制化开发，为客户提供高性能GPU板卡。
#  据Verified Market Research数据统计，2028年GPU市场有望达到2465亿…
#  URL: https://36kr.com/p/1625828648171271
#
#
#
# Article 1
#  Title: 英伟达下一代AD102旗舰GPU规格曝光：144组SM单元/18432 CUDA核心
#  Author: raymon725
#  Description: 在近日遭遇黑客攻击之后，我们已经见到大量的泄露信息，比如低哈希算力（LHR）的旁路技术、深度学习超级采样（DLSS）的源码、以及下一代 GPU 架构的代号。昨日，有报道称 Blackwell 将接替 Hopper GPU，成为英伟达下一代计算卡的代号。现在，我们又知晓了 Ada Lovelace 消费级 GPU 的配置规格。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1242265.htm
#
#
#
# Article 2
#  Title: 传Hopper GPU继任者代号Blackwell 致敬统计数学家大卫·布莱克威尔
#  Author: raymon725
#  Description: 最近发生的黑客攻击事件，泄露了英伟达未来产品规划的一些细节。可知其不仅揭示了 Hopper GPU 继任者 Blackwell，还提到了常规 GPU 产品线的命名。VideoCardz 指出，Blackwell 这个代号，旨在向美国统计学家兼数学家大卫·布莱克韦威尔（David Blackwell）致敬。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1241975.htm
#
#
#
# Article 3
#  Title: Linux补丁曝光AMD下一代Instinct MI300“GFX940”数据中心GPU加速卡
#  Author: raymon725
#  Description: 在最新的 Linux 补丁中，有眼尖的人们发现其包含了一个未发布的 AMD“GFX940”GPU 项目。鉴于其具有与 Aldebaran“GFX90a”GPU 相似的指令集架构（ISA），且支持矩阵融合乘加（MFMA）、全速率 FP64 和 FP32 操作、以及专门针对 CPU+GPU 内存空间集成的功能特性，我们推测它很可能用于 AMD 下一代 Instinct MI300 数据中心 GPU 加速卡。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1242641.htm
#
#
#
# Article 4
#  Title: Gigabyte新推两款英伟达A100水冷服务器：可选2U/4U平台 支持4卡8卡
#  Author: raymon725
#  Description: Gigabyte 刚刚推出了两款基于 AMD 霄龙（EPYC）7003 处理器 + 英伟达 HGX A100 80GB 加速卡的水冷服务器。可知其主打高性能计算（HPC）和人工智能（AI）训练，且有 G262-ZL0 / G492-ZL2 型号可选。为防止计算密集型数据中心过热引发服务器宕机，该公司与 CoolIT Systems 合作开发了独特的散热解决方案。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1240749.htm
#
#
#
# Article 5
#  Title: 正常发挥：SiSoft分享英特尔ARC Alchemist A380 GPU跑分数据
#  Author: raymon725
#  Description: 在抢先分享了英特尔 12 代 Alder Lake-S 酷睿 i9-12900K 台式处理器的跑分之后，知名基准测试公司 SiSoft 又率先披露了定于 2022 年 2 季度到来的英特尔 ARC Alchemist A380 GPU 的官方数据。不过早期数据的准确性仍存在一定的疑问，毕竟英特尔宣称的是台积电 N6 工艺打造，但 SiSoft 指出的却是 TSMC 7nm 。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1239493.htm
#
#
#
# Article 6
#  Title: 出师未捷：Exynos 2200集成的Xclipse 920 GPU表现让人失望
#  Author: raymon725
#  Description: 在 PC 领域，AMD 凭借 RNDA 2 GPU 相对出色的能效表现，在桌面市场收获了高于竞争对手英伟达的口碑。然而在移动设备市场，其与三星携手打造的 Exynos 2200 芯片组，却出现了水土不服的现象。作为 Galaxy S22 系列智能机的可选 SoC 之一（另一版本是高通骁龙 8 Gen 1 芯片组），近期发布的多份 Xclipse 920 GPU 基准测试成绩，都未能如大家所愿。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1239845.htm
#
#
#
# Article 7
#  Title: 爆料称AMD Radeon RX 6950/6750/6650 XT显卡将于4月到来
#  Author: raymon725
#  Description: 知名爆料人 @热心市民描边怪，刚刚在芯域（Chiphell）论坛上分享了与 AMD“RNDA 2 Refresh GPU”有关的产品信息。可知新阵容中包括了 RX 6950 XT、RX 6750 XT 和 RX 6650 XT 等 SKU，且有望于下月正式发布。有趣的是，在这三款显卡之外，红队还有准备提供 RX 6500（非 XT 型号）。与主打 DIY 入门市场的  RX 6400 相比，RX 6500 主要面向 OEM 渠道。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1244489.htm
#
#
#
# Article 8
#  Title: 传英伟达定于9月发布RTX 40系列显卡 旗舰功耗或冲击850W
#  Author: raymon725
#  Description: 早在 GeForce RTX 30 系列显卡上市初期，不少消费者就经历过显卡供电描述含糊而引发的一系列尴尬。没想到的是，传说中定于今年 9 月到来的 GeForce RTX 40 系列显卡，很可能再次打破 800W 的 TDP 功耗。近日有多篇报道指出，基于 Ada Lovelace GPU 架构的下一代英伟达显卡的性能很是惊艳、同时也变得特别费电。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1240163.htm
#
#
#
# Article 9
#  Title: Ryzen 7000 'Raphael' CPU将配全新RDNA2图形架构
#  Author: study875
#  Description: AMD 的下一代 Ryzen 7000 'Raphael' CPU 预计将配全新的 RDNA 2 图形核心架构。这将是台式机阵容的一个重大变化，因为除了 APU 以外，Ryzen CPU 以前没有集成 GPU。知名爆料人士 KOMACHI_ENSAKA 透露，即将推出的 AMD Raphael iGPU 设计利用两个 Workgroup 处理器，允许集成 GPU 提供 4 个 RDNA 2 计算单元。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1240635.htm
#
#
#
# Article 10
#  Title: 英伟达7万多员工密码遭泄露 肇事黑客“开源”190GB机密数据
#  Author: ugmbbc
#  Description: 英伟达核心源码刚“被开源”，7万多员工信息又遭泄露。与此同时，黑客又“帮”三星把代码给开源了，顺便还把高通也捎上了。看起来，南美黑客团伙Lapsus$要和英伟达玩一把大的了。源代码才刚刚“开源”没几天，英伟达71335个员工的电子邮件地址和NTLM密码哈希就被完全泄露了。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1243569.htm
#
#
#
# Article 11
#  Title: CapFrameX曝英伟达RTX 30系显卡存在锁帧不减功耗的问题
#  Author: raymon725
#  Description: 出于各种原因，玩家偶尔需要通过显卡驱动程序来锁定帧速率。在 CPU / GPU 或其它硬件可能遇到瓶颈的情况下，限制 fps 或有助于改善游戏体验。另外当输出帧率超过显示器所支持的刷新率时，此举也有助于节约能源。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1239321.htm
#
#
#
# Article 12
#  Title: 神秘GA102F现身新版AIDA64 或装备在RTX 3090Ti旗舰显卡上
#  Author: study875
#  Description: 在最新版的 AIDA64 中，新增了对 GA102F 的支持。这是一个神秘的 NVIDIA Ampere GPU，目前还没有采用该芯片的新显卡，可能会装备在 NVIDIA 即将推出的旗舰产品 GeForce RTX 3090 Ti 显卡上。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1246479.htm
#
#
#
# Article 13
#  Title: 英特尔：ARC A370M移动GPU具有两倍于Iris Xe核显的性能表现
#  Author: raymon725
#  Description: 在昨日预告将于 3 月 30 日正式公布 ARC Alchemist 移动 GPU 产品线的之后，英特尔又于今日挑逗了一些性能数据。该公司视觉计算事业部副总裁兼总经理 Lisa Pearce 在一篇文章中提到，ARC A370M 高端 SKU（具有 96 EU）将带来两倍于 Iris Xe 核显的提升。显然，与较旧的 DG1 Xe-LP 设计相比，ARC Alchemist 还具有更高的主频、稍高的 TDP、以及改进的高性能架构。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1247205.htm
#
#
#
# Article 14
#  Title: AMDGPU Linux内核驱动程序更新预告 支持跨多个引擎的多用户并发执行
#  Author: raymon725
#  Description: Linux 内核驱动程序即将迎来一个 AMDGPU 的新接口，以支持用户空间的分配和在众多引擎中的并发实现。本周早些时候，长期 AMD 开源 Linux 驱动开发者 Christian König，向该平台的 AMDGPU 直接渲染管理器驱动程序提交了新一批接口补丁。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1244053.htm
#
#
#
# Article 15
#  Title: 传英伟达GeForce RTX 40系显卡有望3季度发布 或支持GDDR7显存
#  Author: raymon725
#  Description: Moore's Law Is Dead 刚刚分享了与英伟达 GeForce RTX 40 系列“Ada Lovelace”显卡相关的详细爆料。传闻称绿队新品会在 2022 年 3 季度到来，并与红队的 AMD RNDA 3（MCM）GPU 展开直接的竞争。首先聊聊功耗，MLID 指出 AIB 合作伙伴已经有成熟的三槽（甚至四槽位）散热解决方案。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1244471.htm
#
#
#
# Article 16
#  Title: 任天堂Switch将配NVIDIA Ampere GPU：支持光追和DLSS
#  Author: study875
#  Description: 根据 NVIDIA 公司近期暴露的信息，让我们了解到很多关于任天堂 Switch 2 主机的规格信息。据悉任天堂的新款游戏主机使用 NVIDIA 的 Ampere GPU，支持光线追踪和 DLSS 2.2。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1242387.htm
#
#
#
# Article 17
#  Title: NVIDIA第一款5nm GPU H100真身首曝
#  Author: ugmbbc
#  Description: 今天晚上，NVIDIA GTC 2022春季开发者大会就将召开，黄仁勋也将发表主题演讲，几乎肯定会发布基于Hopper架构的新一代高性能计算GPU和相关产品。就在最后时刻，H100加速计算卡的渲染图曝光了： 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1249663.htm
#
#
#
# Article 18
#  Title: NVIDIA超级GPU、超级CPU合体 还集成了“网卡”
#  Author: ugmbbc
#  Description: NVIDIA今天同时发布了新一代Hopper H100 GPU核心、Grace CPU处理器，还把二者放在了一张卡上，命名为“Grace Hopper”，官方称之为密度最高达到加速计算系统。两颗芯片并排放置，彼此之间通过NVLink总线进行芯片间通信，带宽达900GB/s。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1249917.htm
#
#
#
# Article 19
#  Title: NVIDIA内部通知：GPU成本价降低8-15％
#  Author: ugmbbc
#  Description: 一个多年来未曾听说的好消息！尤其是挖矿兴起后从未有过的！据悉，NVIDIA近日悄悄通知各家AIC显卡厂商，GPU的成本价降低了8-12％。这意味着，显卡降价有了更大的空间，虽然不代表显卡价格也会应声下降8-12％，但既然NVIDIA都发话了，自然是好兆头。 阅读全文
#  URL: https://www.cnbeta.com/articles/tech/1247827.htm

# %%
IFrame(api.get_everything(q='gpu', language='fr')['articles'][0]['url'],width=1800, height=1000)
# Out:
#         <iframe
#             width="1800"
#             height="1000"
#             src="https://www.journaldugeek.com/2022/03/01/nvidia-le-geant-des-gpu-entierement-compromis-par-une-cyberattaque/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # **Searching Top Headlines by Country**

# %% [markdown]
# | Country  | ISO 3166-1  |
# |---|---|
# | United Arab Emirates  | ae  |
# | Argentina  | ar  |
# |Austria   |at   |
# |Australia   | au  |
# |Belgium   |  be |
# | Bulgaria  |bg   |
# | Brazil  |br   |
# |Canada   |ca   |
# |Switzerland   |ch   |
# | China  |cn   |
# |Colombia   |co   |
# |Cuba   |cu   |
# |Czech Republic   |cz   |
# |Germany   |de   |
# | Egypt  |eg   |
# |France   |fr   |
# |United Kingdom   |gb   |
# |Greece   |gr   |
# |Hong Kong   |hk   |
# |Hungary   |hu   |
# | Indonesia  |id   |
# | Ireland  |ie   |
# | Israel  |il   |
# |India   |in   |
# |Italy   |it   |
# |Japan   |jp   |
# |Republic of Korea   |kr   |
# |Lithuania   |lt   |
# | Latvia  |lv   |
# |Morocco   |ma   |
# |Mexico   |mx   |
# |Malaysia   |my   |
# |Nigeria   |ng   |
# |Netherlands   |nl   |
# |Norway   |no   |
# |New Zeland   |nz   |
# |Philippines   |ph   |
# |Poland   |pl   |
# |Portugal   |pt   |
# | Romania  |ro   |
# | Serbia  |rs   |
# | Russian Federation  |ru   |
# | Saudi Arabia  |sa   |
# |Sweden   |se   |
# |Singapore   |sg   |
# |Slovenia   |si   |
# |Slovakia   |sk   |
# |Thailand   |th   |
# |Turkey   |tr   |
# |Taiwan   |tw   |
# | Ukraine  |ua   |
# |United States   |us   |
# |Venezuela   |ve   |
# |South Africa   |za   |

# %%
country_list = ["United Arab Emirates",	"Argentina",	"Austria",	"Australia",	"Belgium",	"Bulgaria",	"Brazil",	"Canada",	"Switzerland",	"China",	
                "Colombia",	"Cuba",	"Czech Republic",	"Germany",	"Egypt",	"France",	"United Kingdom",	"Greece",	"Hong Kong",	"Hungary",	"Indonesia",	
                "Ireland",	"Israel",	"India",	"Italy",	"Japan",	"Republic of Korea",	"Lithuania",	"Latvia",	"Morocco",	"Mexico",	"Malaysia",	"Nigeria",	
                "Netherlands",	"Norway",	"New Zeland",	"Philippines",	"Poland",	"Portugal",	"Romania",	"Serbia",	"Russian Federation",	"Saudi Arabia",	
                "Sweden",	"Singapore",	"Slovenia",	"Slovakia",	"Thailand",	"Turkey",	"Taiwan",	"Ukraine",	"United States",	"Venezuela",	"South Africa"]

country_codes = ["ae",	"ar",	"at",	"au",	"be",	"bg",	"br",	"ca",	"ch",	"cn",	"co",	"cu",	"cz",	"de",	"eg",	"fr",	"gb",	"gr",	"hk",	"hu",	"id",	"ie",	"il",
                 "in",	"it",	"jp",	"kr",	"lt",	"lv",	"ma",	"mx",	"my",	"ng",	"nl",	"no",	"nz",	"ph",	"pl",	"pt",	"ro",	"rs",	"ru",	"sa",	"se",	"sg",	"si",
                 "sk",	"th",	"tr",	"tw",	"ua",	"us",	"ve",	"za"]

country_dict = dict(zip(country_list,country_codes))

# %%
api.get_top_headlines(q='tech',country=country_dict['United Kingdom'])
# Out:
# {'articles': [{'author': None,
#    'content': 'Artist’s impression of odd radio circles. It is thought to take the rings 1 billion years to reach the size we see them today. The rings are so big (millions of light years across), they’ve expanded … [+5886 chars]',
#    'description': 'Astronomy’s newest mystery objects, odd radio circles or ORCs, have been pulled into sharp focus by an international team of astronomers using the world’s most capable radio telescopes. First revealed by the ASKAP radio telescope, owned and operated by Austra…',
#    'publishedAt': '2022-03-22T09:55:32Z',
#    'source': {'id': None, 'name': 'SciTechDaily'},
#    'title': "Mysterious ORCs in Space Revealed Using the World's Most Powerful Radio Telescopes - SciTechDaily",
#    'url': 'https://scitechdaily.com/mysterious-orcs-in-space-revealed-using-the-worlds-most-powerful-radio-telescopes/',
#    'urlToImage': 'https://scitechdaily.com/images/Odd-Radio-Circles-Artists-Impression-scaled.jpg'},
#   {'author': None,
#    'content': 'NASA’s James Webb Space Telescope. Credit: NASA Goddard Space Flight Center and Northrup Grumman\r\nAfter meeting the major milestone of aligning the telescope to NIRCam, the Webb team is starting to e… [+3005 chars]',
#    'description': 'After meeting the major milestone of aligning the telescope to NIRCam, the Webb team is starting to extend the telescope alignment to the guider (the Fine Guidance Sensor, or FGS) and the other three science instruments. This six-week-long process is called m…',
#    'publishedAt': '2022-03-22T04:29:37Z',
#    'source': {'id': None, 'name': 'SciTechDaily'},
#    'title': 'Webb Space Telescope Begins Multi-Instrument Alignment - SciTechDaily',
#    'url': 'https://scitechdaily.com/webb-space-telescope-begins-multi-instrument-alignment/',
#    'urlToImage': 'https://scitechdaily.com/images/NASAs-Webb-Space-Telescope.gif'}],
#  'status': 'ok',
#  'totalResults': 2}

# %% [markdown]
# # **References and Additional Learning**

# %% [markdown]
# ## **Websites**
#
# - **[News API](https://newsapi.org/docs) Documentation**

# %% [markdown]
# # **Connect**
# - **Feel free to connect with Adrian on [YouTube](https://www.youtube.com/channel/UCPuDxI3xb_ryUUMfkm0jsRA), [LinkedIn](https://www.linkedin.com/in/adrian-dolinay-frm-96a289106/), [Twitter](https://twitter.com/DolinayG) and [GitHub](https://github.com/ad17171717). Happy coding!**
