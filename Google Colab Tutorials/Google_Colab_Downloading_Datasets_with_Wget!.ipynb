# %% [markdown]
# <a href="https://colab.research.google.com/github/ad17171717/YouTube-Tutorials/blob/main/Google%20Colab%20Tutorials/Google_Colab_Downloading_Datasets_with_Wget!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import platform

# %% [markdown]
# # **Wget**
#
# **Wget is a software package for retrieving files using HTTP, HTTPS, FTP and FTPS internet protocols. It is a non-interactive commandline tool, meaning the package can be called from scripts.**

# %% [markdown]
# <sup>Source: [GNU Wget](https://www.gnu.org/software/wget/) from gnu.org</sup>

# %%
platform.platform()
# Out:
# 'Linux-5.10.147+-x86_64-with-glibc2.31'

# %% [markdown]
# ## **Downloading Data into the Current Directory**

# %%
# !pwd
# Out:
# /content

# %%
# !wget https://www.fdic.gov/bank/individual/failed/banklist.csv
# Out:
# --2023-05-05 19:14:13--  https://www.fdic.gov/bank/individual/failed/banklist.csv
# Resolving www.fdic.gov (www.fdic.gov)... 18.172.170.90, 18.172.170.63, 18.172.170.128, ...
# Connecting to www.fdic.gov (www.fdic.gov)|18.172.170.90|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/banklist.csv [following]
# URL transformed to HTTPS due to an HSTS policy
# --2023-05-05 19:14:13--  https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/banklist.csv
# Reusing existing connection to www.fdic.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 45120 (44K) [text/csv]
# Saving to: ‘banklist.csv’
#
# banklist.csv        100%[===================>]  44.06K  --.-KB/s    in 0.005s
#
# 2023-05-05 19:14:13 (7.83 MB/s) - ‘banklist.csv’ saved [45120/45120]

# %%
bank_df = pd.read_csv('/content/banklist.csv',encoding = 'ISO-8859-1')
bank_df
# Out:
#                             Bank Name               City  State   Cert   \
# 0                  First Republic Bank      San Francisco     CA  59017
# 1                       Signature Bank           New York     NY  57053
# 2                  Silicon Valley Bank        Santa Clara     CA  24735
# 3                    Almena State Bank             Almena     KS  15426
# 4           First City Bank of Florida  Fort Walton Beach     FL  16748
# ..                                 ...                ...    ...    ...
# 561                 Superior Bank, FSB           Hinsdale     IL  32646
# 562                Malta National Bank              Malta     OH   6629
# 563    First Alliance Bank & Trust Co.         Manchester     NH  34264
# 564  National State Bank of Metropolis         Metropolis     IL   3815
# 565                   Bank of Honolulu           Honolulu     HI  21029
#
#                   Acquiring Institution  Closing Date    Fund
# ...

# %% [markdown]
# ## **Downloading Data into a Specified Directory**

# %%
# !mkdir data_folder

# %%
# !wget https://data.sa.gov.au/data/dataset/d385385a-6d79-4ef7-ab0f-0cfc583469f6/resource/7223f681-d340-4fc9-b92b-403d158f521f/download/sa-government-enrolments-by-school.csv -P /content/data_folder
# Out:
# --2023-05-05 19:17:06--  https://data.sa.gov.au/data/dataset/d385385a-6d79-4ef7-ab0f-0cfc583469f6/resource/7223f681-d340-4fc9-b92b-403d158f521f/download/sa-government-enrolments-by-school.csv
# Resolving data.sa.gov.au (data.sa.gov.au)... 52.62.112.34, 52.64.82.196, 52.63.94.204
# Connecting to data.sa.gov.au (data.sa.gov.au)|52.62.112.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96996 (95K) [text/csv]
# Saving to: ‘/content/data_folder/sa-government-enrolments-by-school.csv’
#
# sa-government-enrol 100%[===================>]  94.72K   337KB/s    in 0.3s
#
# 2023-05-05 19:17:07 (337 KB/s) - ‘/content/data_folder/sa-government-enrolments-by-school.csv’ saved [96996/96996]

# %%
school_data = pd.read_csv('/content/data_folder/sa-government-enrolments-by-school.csv')
school_data
# Out:
#      School_Number                       School_Name  \
# 0              102           East Murray Area School
# 1              104  Coromandel Valley Primary School
# 2              106         Cowandilla Primary School
# 3              107            Crafers Primary School
# 4              111      Crystal Brook Primary School
# ..             ...                               ...
# 697           1908         Lake Windemere B-7 School
# 698           1913           Riverbanks College B-12
# 699           1914          Aldinga Payinthi College
# 700           1915          Goolwa Secondary College
# 701           1919      Adelaide Botanic High School
#
#                     School_Type             Suburb  Post_Code   Latitude  \
# 0             Primary Education           Mindarie       5309 -34.739441
# 1             Primary Education  Coromandel Valley       5051 -35.033562
# 2             Primary Education         Cowandilla       5033 -34.934160
# ...

# %% [markdown]
# ## **Downloading Multiple Datasets**

# %%
url_list = ['https://www2.census.gov/programs-surveys/saipe/datasets/2021/2021-school-districts/ussd21.xls',
            'https://www2.census.gov/programs-surveys/saipe/datasets/2020/2020-school-districts/ussd20.xls',
            'https://www2.census.gov/programs-surveys/saipe/datasets/2019/2019-school-districts/ussd19.xls',
            'https://www2.census.gov/programs-surveys/saipe/datasets/2018/2018-school-districts/ussd18.xls']

# %%
with open('url_list.txt','w') as txt:
  for url in url_list:
    txt.write(f'{url}\n')

# %%
# !wget -i /content/url_list.txt
# Out:
# --2023-05-05 19:20:46--  https://www2.census.gov/programs-surveys/saipe/datasets/2021/2021-school-districts/ussd21.xls
# Resolving www2.census.gov (www2.census.gov)... 104.81.185.153, 2600:1409:12:286::208c, 2600:1409:12:2b9::208c
# Connecting to www2.census.gov (www2.census.gov)|104.81.185.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/vnd.ms-excel]
# Saving to: ‘ussd21.xls’
#
# ussd21.xls              [ <=>                ]   1.82M  --.-KB/s    in 0.1s
#
# 2023-05-05 19:20:47 (14.4 MB/s) - ‘ussd21.xls’ saved [1908224]
#
# --2023-05-05 19:20:47--  https://www2.census.gov/programs-surveys/saipe/datasets/2020/2020-school-districts/ussd20.xls
# Reusing existing connection to www2.census.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/vnd.ms-excel]
# Saving to: ‘ussd20.xls’
#
# ussd20.xls              [ <=>                ]   1.77M  --.-KB/s    in 0.08s
#
# ...

# %%
saide_2018 = pd.read_excel('/content/ussd18.xls',skiprows=2)
saide_2018
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 0                    AL                1          190
# 1                    AL                1            5
# 2                    AL                1           30
# 3                    AL                1           60
# 4                    AL                1           90
# ...                 ...              ...          ...
# 13202                WY               56         6240
# 13203                WY               56         5820
# 13204                WY               56         4830
# 13205                WY               56         6090
# 13206                PR               72           30
#
#                                       Name  Estimated Total Population  \
# 0           Alabaster City School District                       34383
# 1         Albertville City School District                       21914
# 2      Alexander City City School District                       16996
# ...

# %%
saide_2019 = pd.read_excel('/content/ussd19.xls',skiprows=2)
saide_2019
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 0                    AL                1          190
# 1                    AL                1            5
# 2                    AL                1           30
# 3                    AL                1           60
# 4                    AL                1           90
# ...                 ...              ...          ...
# 13179                WY               56         6240
# 13180                WY               56         5820
# 13181                WY               56         4830
# 13182                WY               56         6090
# 13183                PR               72           30
#
#                                       Name  Estimated Total Population  \
# 0           Alabaster City School District                       34669
# 1         Albertville City School District                       22051
# 2      Alexander City City School District                       16920
# ...

# %% [markdown]
# # **References and Additional Learning**

# %% [markdown]
# ## **Datasets**
#
# - **[Census Datasets](https://www.census.gov/data/datasets.html) from Census.gov**
#
# - **[Enrolments by school](https://data.sa.gov.au/data/dataset/school-enrolments) from Data.sa**
#
# - **[FDIC Failed Bank List](https://catalog.data.gov/dataset/fdic-failed-bank-list) from Data.gov**

# %% [markdown]
# ## **Website**
#
# - **[GNU Wget](https://www.gnu.org/software/wget/) from gnu.org**

# %% [markdown]
# # **Connect**
# - **Feel free to connect with Adrian on [YouTube](https://www.youtube.com/channel/UCPuDxI3xb_ryUUMfkm0jsRA), [LinkedIn](https://www.linkedin.com/in/adrian-dolinay-frm-96a289106/), [Twitter](https://twitter.com/DolinayG), [GitHub](https://github.com/ad17171717), [Medium](https://adriandolinay.medium.com/) and [Odysee](https://odysee.com/@adriandolinay:0). Happy coding!**
