# %% [markdown]
# <a href="https://colab.research.google.com/github/ad17171717/YouTube-Tutorials/blob/main/Python/JSON/Python!_Reading_and_Writing_JSON_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# %% [markdown]
# # **JSON**
#
# **JSON (JavaScript Object Notation) is a lightweight data-interchange format based on a subset of the JavaScript Programming Language. The text format is independent of language, meaning JSON files can be read or written using Python, R, C++, Rust and many other programming languages.**
#
# **JSON is widely used for interacting with application programming interfaces (APIs) on the web.**
#
# **There are two structures that JSON is built upon: an ordered list with values, and a collection of name and value pairs. Within Python these two structures correspond to lists and dictionaries.**

# %% [markdown]
# <sup>Source: [Introducing JSON](https://www.json.org/json-en.html) from json.org<sup/>
#
# <sup>Source: [Introduction to Using JSON With Data Analytics](https://bootcamp.berkeley.edu/resources/coding/learn-data-analytics/introduction-to-using-json-with-data-analytics/) from Berkeley.edu<sup/>
#
# <sup>Source: [Using Web APIs with JSON](http://ai2.appinventor.mit.edu/reference/other/json-web-apis.html) from MIT App Inventor<sup/>

# %% [markdown]
# ## **Reading a JSON file**

# %%
with open('playlist_data.json', 'r') as read_file:
    #the json file is read into a nested dictionary
    playlist_dict = json.load(read_file)

# %%
playlist_dict.keys()
# Out:
# dict_keys(['info', 'playlists'])

# %%
playlist_dict['info']
# Out:
# {'generated_on': '2017-12-03 08:41:42.057563',
#  'slice': '0-999',
#  'version': 'v1'}

# %%
type(playlist_dict['playlists'])
# Out:
# list

# %% [markdown]
# ### **Parsing the JSON data**

# %%
#iterate through the playlists from the json file
for paylist in playlist_dict['playlists']:
    print(paylist['name'])
# Out:
# Throwbacks
# Awesome Playlist
# korean
# mat
# 90s
# Wedding
# I Put A Spell On You
# 2017
# BOP
# old country
# abby
# VIBE
# relax
# sleep
# 90's
# New Songs
# slow hands
# Mom's playlist
# SARAH
# melancholy
# mixtape
# Sad Songs
# fall '17
# ✔️
# Twenty one pilots
# run it
# Winter 2014
# smooth
# Yeet
# groovy
# Garage Rock
# Running 2.0
# acoustic
# morning
# good good
# Good Vibes
#  indie rock
# Hits
# tb
# Country
# 2020
# Belters
# Road Trippin'
# Country
# taylor swift
# angst
# Running 2
# Spring 2016
# Country
# Gospel
# SB
# Kevin
# Christmas
# NB
# Smooth Jazz
# Tennessee
# funky
# spring 16
# Gates
# Favorite Songs
# Ski
# Country
# hype
# Awesome Mix
# Elizabeth
# PlayStation
# Ashley
# chill
# xx
# art class
# Random Tunes
# boat
# spanish jams
# new
# CR
# Run!!
# winter '17
# Workout
# Traps
# Dope
# Chill
# rap
# Gospel
# Florida
# Workout2
# Gym
# Zoned
# relax
# KPOP
# 80's
# For the Road
# R & B
# Tom Petty
# Catchy Songs
# relax
# roadtrippin
# christmas
# ...

# %%
for idx,paylist in enumerate(playlist_dict['playlists']):
    if paylist['name'] == 'Rap Classics':
        print(idx)
# Out:
# 170

# %%
rap_dict = playlist_dict['playlists'][170]
rap_dict
# Out:
# {'name': 'Rap Classics',
#  'collaborative': 'false',
#  'pid': 170,
#  'modified_at': 1476144000,
#  'num_tracks': 52,
#  'num_albums': 42,
#  'num_followers': 1,
#  'tracks': [{'pos': 0,
#    'artist_name': 'Ice Cube',
#    'track_uri': 'spotify:track:2qOm7ukLyHUXWyR4ZWLwxA',
#    'artist_uri': 'spotify:artist:3Mcii5XWf6E0lrY3Uky4cA',
#    'track_name': 'It Was A Good Day',
#    'album_uri': 'spotify:album:71HM1CMYWeZzws8pyiEn46',
#    'duration_ms': 260000,
#    'album_name': 'The Predator'},
#   {'pos': 1,
#    'artist_name': 'The Notorious B.I.G.',
#    'track_uri': 'spotify:track:2g8HN35AnVGIk7B8yMucww',
#    'artist_uri': 'spotify:artist:5me0Irg2ANcsgc93uaYrpb',
#    'track_name': 'Big Poppa',
#    'album_uri': 'spotify:album:2HTbQ0RHwukKVXAlTmCZP2',
#    'duration_ms': 252746,
#    'album_name': 'Ready To Die The Remaster'},
#   {'pos': 2,
#    'artist_name': 'Snoop Dogg',
#    'track_uri': 'spotify:track:0WKYRFtH6KKbaNWjsxqm70',
# ...

# %%
for song_data in rap_dict['tracks']:
    print(f'Artist: {song_data["artist_name"]} Song: {song_data["track_name"]}')
# Out:
# Artist: Ice Cube Song: It Was A Good Day
# Artist: The Notorious B.I.G. Song: Big Poppa
# Artist: Snoop Dogg Song: Gin And Juice (feat. Dat Nigga Daz)
# Artist: 2Pac Song: Ambitionz Az A Ridah
# Artist: Geto Boys Song: Damn It Feels Good to Be a Gangsta
# Artist: 2Pac Song: California Love - Original Version
# Artist: DMX Song: It's All Good
# Artist: The Notorious B.I.G. Song: Warning
# Artist: N.W.A. Song: Straight Outta Compton
# Artist: Eazy-E Song: Boyz-N-The-Hood
# Artist: Wu-Tang Clan Song: C.R.E.A.M.
# Artist: Ice Cube Song: Check Yo Self - Remix;
# Artist: Snoop Dogg Song: Who Am I (What's My Name)?
# Artist: 2Pac Song: All Eyez On Me
# Artist: The Notorious B.I.G. Song: Hypnotize - 2014 Remastered Version
# Artist: Coolio Song: Gangsta's Paradise
# Artist: Cypress Hill Song: Insane in the Brain
# Artist: Eazy-E Song: Real Muthaphuckkin' G's
# Artist: Luniz Song: I Got 5 On It - Feat. Michael Marshall
# Artist: Nas Song: N.Y. State of Mind
# ...

# %% [markdown]
# ## **Writing a JSON file**

# %%
with open('rap_classics.json', 'w') as outfile:
    json.dump(rap_dict, outfile)

# %% [markdown]
# # **References and Additional Learning**

# %% [markdown]
# ## **Dataset**
#
# - **[spotify-millions-playlist](https://www.kaggle.com/datasets/adityak80/spotify-millions-playlist?resource=download) from Kaggle by Aditya Kumar**

# %% [markdown]
# ## **Websites**
#
# - **[Introducing JSON](https://www.json.org/json-en.html) from json.org**
#
# - **[Introduction to Using JSON With Data Analytics](https://bootcamp.berkeley.edu/resources/coding/learn-data-analytics/introduction-to-using-json-with-data-analytics/) from Berkeley.edu**
#
# - **[Using Web APIs with JSON](http://ai2.appinventor.mit.edu/reference/other/json-web-apis.html) from MIT App Inventor**

# %% [markdown]
# # **Connect**
# - **Feel free to connect with Adrian on [YouTube](https://www.youtube.com/channel/UCPuDxI3xb_ryUUMfkm0jsRA), [LinkedIn](https://www.linkedin.com/in/adrian-dolinay-frm-96a289106/), [Twitter](https://twitter.com/DolinayG), [GitHub](https://github.com/ad17171717), [Medium](https://adriandolinay.medium.com/) and [Odysee](https://odysee.com/@adriandolinay:0). Happy coding!**
